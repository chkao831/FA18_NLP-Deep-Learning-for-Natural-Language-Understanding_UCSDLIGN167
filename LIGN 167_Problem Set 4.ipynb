# %% [markdown]
# ## LIGN 167: Problem Set 4
# ### Name: Chih-Hsuan Kao
# ### Date: December 3, 2018

# %% [markdown]
# An implementation of a simple RNN (an Elman network) in PyTorch.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import spacy


###### DATA PROCESSING STARTS #########


def load_corpus():
    #this loads the data from sample_corpus.txt
    with open('/Users/carolynkao/Desktop/LIGN167/psa5/sample_corpus.txt','r') as f:
        corpus = f.read().replace('\n','')
    return corpus
corpus = load_corpus()
corpus

# %%
def segment_and_tokenize(corpus):
    #make sure to run: python -m spacy download en 
    #in the command line before using this!

    #corpus is assumed to be a string, containing the entire corpus
    nlp = spacy.load('en')
    tokens = nlp(corpus)
    sents = [[t.text for t in s] for s in tokens.sents if len([t.text for t in s])>1]
    sents = remove_infrequent_words(sents)
    sents = [['<START>']+s+['<END>'] for s in sents]
    return sents

sents2 = segment_and_tokenize(load_corpus())
sents2
# Out:
# [['<START>',
#   '<UNKOWN>',
#   ',',
#   'baby',
#   'animals',
#   'who',
#   'are',
#   '<UNKOWN>',
#   'by',
#   'their',
#   'parents',
#   'are',
#   'no',
#   'longer',
#   'kept',
#   'in',
#   'the',
#   '<UNKOWN>',
#   "'s",
#   '<UNKOWN>',
#   'because',
#   'the',
#   '<UNKOWN>',
#   'has',
#   'found',
#   'that',
#   'it',
#   'is',
#   '<UNKOWN>',
#   'to',
#   '<UNKOWN>',
#   'them',
#   'into',
#   'their',
#   '<UNKOWN>',
#   'once',
#   'they',
#   '<UNKOWN>',
#   'up',
#   'if',
#   'they',
#   'are',
#   'kept',
#   'away',
#   'from',
#   'their',
#   'own',
#   'species',
#   '.Some',
#   '<END>'],
#  ['<START>',
#   'people',
#   'think',
#   'that',
#   'before',
#   'becoming',
#   'a',
#   'god',
#   ',',
#   'he',
#   'was',
#   'a',
#   'Chinese',
#   '<UNKOWN>',
#   'and',
#   'a',
#   '<UNKOWN>',
#   'of',
#   'a',
#   '<UNKOWN>',
#   'god',
#   '.The',
#   '<END>'],
#  ['<START>',
#   'Grand',
#   'Canyon',
#   'is',
#   'a',
#   'very',
#   'large',
#   '<UNKOWN>',
#   'in',
#   'Arizona',
#   ',',
#   'United',
#   'States',
#   '.',
#   '<END>'],
#  ['<START>',
#   'It',
#   'is',
#   'a',
#   'national',
#   'park',
#   'of',
#   'the',
#   'United',
#   'States',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   'father',
#   'and',
#   'son',
#   'were',
#   'not',
#   '<UNKOWN>',
#   ';',
#   'John',
#   '<UNKOWN>',
#   ',',
#   'said',
#   'that',
#   'the',
#   'father',
#   'would',
#   'not',
#   'even',
#   'go',
#   '<UNKOWN>',
#   'his',
#   'son',
#   "'s",
#   'house',
#   'if',
#   'he',
#   'could',
#   'keep',
#   '<UNKOWN>',
#   'of',
#   'it',
#   ',',
#   'and',
#   'believed',
#   'that',
#   'Jane',
#   'would',
#   'probably',
#   'kill',
#   'her',
#   '<UNKOWN>',
#   '.It',
#   'is',
#   'situated',
#   'on',
#   'the',
#   'river',
#   '<UNKOWN>',
#   ',',
#   '11',
#   'km',
#   'northwest',
#   'of',
#   '<UNKOWN>',
#   ',',
#   'and',
#   '14',
#   'km',
#   'southwest',
#   'of',
#   '<UNKOWN>',
#   '.The',
#   'colony',
#   ',',
#   'near',
#   'the',
#   'coast',
#   'on',
#   'the',
#   '<UNKOWN>',
#   'River',
#   ',',
#   'was',
#   'called',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   'cooking',
#   'programs',
#   'brought',
#   'the',
#   '<UNKOWN>',
#   'of',
#   '<UNKOWN>',
#   'to',
#   'a',
#   'new',
#   '<UNKOWN>',
#   'who',
#   'wanted',
#   'to',
#   '<UNKOWN>',
#   'out',
#   'new',
#   'ways',
#   'of',
#   'cooking',
#   '<UNKOWN>',
#   'is',
#   'a',
#   'city',
#   'in',
#   'the',
#   'German',
#   'state',
#   'of',
#   'North',
#   'Rhine',
#   '-',
#   'Westphalia',
#   ',',
#   'in',
#   'the',
#   '<UNKOWN>',
#   'Area',
#   'and',
#   'has',
#   'about',
#   '100,000',
#   'inhabitants',
#   '.The',
#   'greenhouse',
#   'effect',
#   'is',
#   '<UNKOWN>',
#   'by',
#   'greenhouse',
#   'gases',
#   ';',
#   'the',
#   'most',
#   'important',
#   'greenhouse',
#   '<UNKOWN>',
#   'in',
#   'Earth',
#   "'s",
#   '<UNKOWN>',
#   'are',
#   ':',
#   'water',
#   '<UNKOWN>',
#   ',',
#   'carbon',
#   '<UNKOWN>',
#   ',',
#   'and',
#   'methane',
#   '.The',
#   '<END>'],
#  ['<START>',
#   'name',
#   '<UNKOWN>',
#   'is',
#   'from',
#   '<UNKOWN>',
#   'in',
#   '<UNKOWN>',
#   '.Their',
#   '<END>'],
#  ['<START>',
#   'music',
#   'can',
#   'be',
#   'described',
#   'as',
#   'a',
#   '<UNKOWN>',
#   'between',
#   'heavy',
#   'metal',
#   'and',
#   'rock',
#   "'",
#   'n',
#   "'",
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'only',
#   ';',
#   'the',
#   '<UNKOWN>',
#   'will',
#   'not',
#   'process',
#   '<UNKOWN>',
#   'for',
#   'non',
#   '-',
#   '<UNKOWN>',
#   '.The',
#   'following',
#   'is',
#   'a',
#   'list',
#   'of',
#   '<UNKOWN>',
#   'hurricane',
#   'seasons',
#   '.The',
#   'term',
#   '``',
#   '<UNKOWN>',
#   "''",
#   'gained',
#   '<UNKOWN>',
#   'during',
#   'World',
#   'War',
#   'II',
#   ',',
#   'when',
#   'many',
#   '<UNKOWN>',
#   'from',
#   'the',
#   'United',
#   'States',
#   'were',
#   '<UNKOWN>',
#   'in',
#   'Australia',
#   ',',
#   'which',
#   'probably',
#   '<UNKOWN>',
#   'its',
#   'being',
#   'adopted',
#   'by',
#   'elements',
#   'of',
#   'the',
#   'Australian',
#   'media',
#   'at',
#   'the',
#   'time',
#   '.The',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'with',
#   'the',
#   'North',
#   'Riding',
#   'of',
#   'Yorkshire',
#   'was',
#   '<UNKOWN>',
#   ':',
#   'the',
#   'part',
#   'of',
#   'the',
#   'town',
#   'of',
#   '<UNKOWN>',
#   'Castle',
#   'that',
#   'was',
#   'in',
#   'Yorkshire',
#   'was',
#   'added',
#   'to',
#   'County',
#   'Durham',
#   ',',
#   'but',
#   'the',
#   'part',
#   'of',
#   'the',
#   'Borough',
#   'of',
#   '<UNKOWN>',
#   '-',
#   'on',
#   '-',
#   '<UNKOWN>',
#   'in',
#   'Durham',
#   'was',
#   'given',
#   'to',
#   'the',
#   'North',
#   'Riding',
#   '.But',
#   '<END>'],
#  ['<START>',
#   'I',
#   'was',
#   'here',
#   'in',
#   'New',
#   'York',
#   'City',
#   ',',
#   'I',
#   'had',
#   'money',
#   '<END>'],
#  ['<START>',
#   'and',
#   'I',
#   'could',
#   "n't",
#   '<UNKOWN>',
#   'any',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'was',
#   '<UNKOWN>',
#   'by',
#   'John',
#   'the',
#   '<UNKOWN>',
#   '.His',
#   '<END>'],
#  ['<START>',
#   'original',
#   '<UNKOWN>',
#   'in',
#   'writing',
#   '<UNKOWN>',
#   '451',
#   'was',
#   'to',
#   'show',
#   'his',
#   '<UNKOWN>',
#   'love',
#   'for',
#   'books',
#   'and',
#   'libraries',
#   '.Two',
#   'federal',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'were',
#   'founded',
#   'on',
#   'the',
#   'island',
#   'in',
#   '1961',
#   '.The',
#   '<END>'],
#  ['<START>',
#   'female',
#   'flowers',
#   ',',
#   'called',
#   '<UNKOWN>',
#   ',',
#   'are',
#   'used',
#   'for',
#   'making',
#   '<UNKOWN>',
#   '.In',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   ',',
#   'people',
#   'are',
#   'able',
#   'to',
#   're',
#   '-',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'events',
#   'in',
#   'their',
#   'past',
#   '<UNKOWN>',
#   'is',
#   'the',
#   '<UNKOWN>',
#   'of',
#   'writing',
#   '.As',
#   '<END>'],
#  ['<START>',
#   'a',
#   'young',
#   'child',
#   'he',
#   'often',
#   'went',
#   'to',
#   'St',
#   'James',
#   "'",
#   'Park',
#   'with',
#   'his',
#   'father',
#   'to',
#   'watch',
#   'Newcastle',
#   'United',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'is',
#   'the',
#   'legislature',
#   'of',
#   'Germany',
#   '.Only',
#   '<END>'],
#  ['<START>',
#   'two',
#   'months',
#   'earlier',
#   'his',
#   'former',
#   'friend',
#   'and',
#   '<UNKOWN>',
#   'member',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'had',
#   'also',
#   'died',
#   '.The',
#   'word',
#   '<UNKOWN>',
#   'is',
#   'used',
#   'now',
#   '.The',
#   '<END>'],
#  ['<START>',
#   'same',
#   'year',
#   'the',
#   'company',
#   '<UNKOWN>',
#   'its',
#   'symbol',
#   '-',
#   'the',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '.',
#   '<END>'],
#  ['<START>',
#   'In',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'became',
#   'a',
#   '<UNKOWN>',
#   'company',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'first',
#   'in',
#   'the',
#   '<UNKOWN>',
#   'tournament',
#   ',',
#   '1',
#   '<UNKOWN>',
#   'points',
#   '<UNKOWN>',
#   'of',
#   '<UNKOWN>',
#   ',',
#   'who',
#   'was',
#   'out',
#   'of',
#   'practice',
#   'and',
#   'made',
#   'a',
#   '<UNKOWN>',
#   'start',
#   '.The',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'are',
#   'then',
#   '<UNKOWN>',
#   'and',
#   're',
#   '-',
#   '<UNKOWN>',
#   'at',
#   'the',
#   'end',
#   '.Its',
#   '<UNKOWN>',
#   'was',
#   'announced',
#   'by',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'Sheppard',
#   ',',
#   'David',
#   'C.',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   'and',
#   'Brian',
#   'G.',
#   'Marsden',
#   'on',
#   'April',
#   '13',
#   ',',
#   '2007',
#   ',',
#   'from',
#   '<UNKOWN>',
#   'taken',
#   'between',
#   'January',
#   '5',
#   ',',
#   '2006',
#   'and',
#   'March',
#   '22',
#   ',',
#   '2007',
#   '<END>'],
#  ['<START>',
#   'Grosso',
#   'do',
#   '<UNKOWN>',
#   'means',
#   '``',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   "''",
#   '.',
#   '<END>'],
#  ['<START>',
#   'The',
#   'name',
#   'comes',
#   'from',
#   'its',
#   'northern',
#   '<UNKOWN>',
#   'state',
#   'of',
#   '<UNKOWN>',
#   'Grosso',
#   '.Then',
#   ',',
#   'he',
#   'goes',
#   'to',
#   'his',
#   'son',
#   "'s",
#   '<UNKOWN>',
#   'party',
#   ',',
#   'where',
#   'his',
#   'wife',
#   ',',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   'for',
#   'a',
#   '<UNKOWN>',
#   '.It',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'and',
#   '<UNKOWN>',
#   'on',
#   'the',
#   'north',
#   'and',
#   'the',
#   'east',
#   '.She',
#   '<UNKOWN>',
#   'her',
#   'first',
#   'leading',
#   'role',
#   'as',
#   '<UNKOWN>',
#   'in',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '.Its',
#   '<END>'],
#  ['<START>', 'county', 'seat', 'is', '<UNKOWN>', '.At', '<END>'],
#  ['<START>',
#   'the',
#   'age',
#   'of',
#   'five',
#   ',',
#   'John',
#   'was',
#   '<UNKOWN>',
#   'from',
#   'the',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '.A',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'is',
#   'the',
#   '<UNKOWN>',
#   'unit',
#   'of',
#   '<UNKOWN>',
#   '.It',
#   'is',
#   'not',
#   'being',
#   'used',
#   'any',
#   'more',
#   'and',
#   'at',
#   'the',
#   '<UNKOWN>',
#   'the',
#   '<UNKOWN>',
#   'is',
#   'buried',
#   'underneath',
#   'a',
#   'public',
#   'park',
#   'in',
#   'a',
#   '<UNKOWN>',
#   'called',
#   '<UNKOWN>',
#   'Park',
#   'in',
#   'the',
#   'City',
#   'of',
#   '<UNKOWN>',
#   ',',
#   'which',
#   'is',
#   'in',
#   'the',
#   'State',
#   'of',
#   'New',
#   'South',
#   'Wales',
#   'Australia',
#   '.The',
#   '<UNKOWN>',
#   'are',
#   '<UNKOWN>',
#   'for',
#   'cotton',
#   'or',
#   'tobacco',
#   '<UNKOWN>',
#   'as',
#   'the',
#   'cotton',
#   '<UNKOWN>',
#   'or',
#   'tobacco',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   'Gironde',
#   'is',
#   'a',
#   'commune',
#   '.Only',
#   '<END>'],
#  ['<START>',
#   'eight',
#   'tropical',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   'and',
#   'four',
#   '<UNKOWN>',
#   '.The',
#   '<END>'],
#  ['<START>',
#   '1998',
#   '<UNKOWN>',
#   'World',
#   'Cup',
#   'was',
#   'a',
#   'football',
#   '<UNKOWN>',
#   'event',
#   'that',
#   'was',
#   'held',
#   'in',
#   'France',
#   'from',
#   'June',
#   '10',
#   '1998',
#   'to',
#   'July',
#   '12',
#   ',',
#   '1998',
#   '<UNKOWN>',
#   'is',
#   'an',
#   'area',
#   'of',
#   '<UNKOWN>',
#   'to',
#   'tourists',
#   'because',
#   'it',
#   'has',
#   'many',
#   'historic',
#   'and',
#   '<UNKOWN>',
#   'half',
#   '-',
#   '<UNKOWN>',
#   'buildings',
#   '<END>'],
#  ['<START>',
#   '.It',
#   'was',
#   'probably',
#   'the',
#   'most',
#   'popular',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'of',
#   'the',
#   '<UNKOWN>',
#   'century',
#   '<UNKOWN>',
#   'can',
#   'not',
#   'find',
#   'his',
#   '<UNKOWN>',
#   ',',
#   'and',
#   'realizes',
#   'that',
#   '<UNKOWN>',
#   'has',
#   'it',
#   '.The',
#   '<END>'],
#  ['<START>',
#   'second',
#   'reference',
#   ',',
#   'the',
#   '<UNKOWN>',
#   'decided',
#   'that',
#   'the',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'referred',
#   '-',
#   'section',
#   '4',
#   'of',
#   'the',
#   'School',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   '-',
#   'was',
#   '``',
#   '<UNKOWN>',
#   'to',
#   'the',
#   '<UNKOWN>',
#   "''",
#   '.In',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   ',',
#   'he',
#   'published',
#   'the',
#   '<UNKOWN>',
#   'Chronicles',
#   ',',
#   'also',
#   'known',
#   'as',
#   'the',
#   'World',
#   'Chronicles',
#   ',',
#   'an',
#   '<UNKOWN>',
#   'history',
#   'of',
#   'the',
#   'world',
#   'from',
#   'the',
#   '<UNKOWN>',
#   'to',
#   'the',
#   'present',
#   'day',
#   '.The',
#   '<END>'],
#  ['<START>',
#   'WWF',
#   '<UNKOWN>',
#   'of',
#   'Stone',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'Austin',
#   ',',
#   'Kurt',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   ',',
#   'and',
#   'the',
#   'Undertaker',
#   ',',
#   'who',
#   'all',
#   '<UNKOWN>',
#   'against',
#   'the',
#   'team',
#   'of',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   ',',
#   'and',
#   'the',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'is',
#   'a',
#   'commune',
#   '.',
#   '<END>'],
#  ['<START>',
#   'It',
#   'is',
#   'found',
#   'in',
#   'the',
#   'region',
#   'Basse',
#   '-',
#   'Normandie',
#   'in',
#   'the',
#   'Calvados',
#   'department',
#   'in',
#   'the',
#   'northwest',
#   'of',
#   'France',
#   '.In',
#   '<END>'],
#  ['<START>',
#   'China',
#   ',',
#   'the',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'as',
#   'the',
#   'de',
#   '<UNKOWN>',
#   'state',
#   'religion',
#   ',',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'based',
#   'on',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'as',
#   'an',
#   'entrance',
#   '<UNKOWN>',
#   'into',
#   'government',
#   'service',
#   '.So',
#   'to',
#   'create',
#   '<UNKOWN>',
#   ',',
#   'the',
#   '<UNKOWN>',
#   'took',
#   'covers',
#   'and',
#   'paper',
#   'from',
#   '<UNKOWN>',
#   'and',
#   'church',
#   '<UNKOWN>',
#   'and',
#   'created',
#   'paper',
#   '<UNKOWN>',
#   ',',
#   'which',
#   'were',
#   '<UNKOWN>',
#   'using',
#   'the',
#   'same',
#   '<UNKOWN>',
#   'that',
#   'were',
#   '<UNKOWN>',
#   'used',
#   'to',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   'related',
#   'to',
#   'the',
#   '<UNKOWN>',
#   'area',
#   'of',
#   '<UNKOWN>',
#   '.A',
#   '<END>'],
#  ['<START>',
#   'ways',
#   'into',
#   'the',
#   'match',
#   ',',
#   'Jeff',
#   '<UNKOWN>',
#   'Chavo',
#   'on',
#   'the',
#   'Spanish',
#   'commentary',
#   'desk',
#   ',',
#   'Jeff',
#   '<UNKOWN>',
#   'a',
#   'ladder',
#   'and',
#   '<UNKOWN>',
#   'off',
#   'it',
#   'landing',
#   'on',
#   'Chavo',
#   'and',
#   '<UNKOWN>',
#   'the',
#   'desk',
#   '.The',
#   'monastery',
#   'has',
#   'a',
#   '<UNKOWN>',
#   'and',
#   'various',
#   'service',
#   'buildings',
#   'around',
#   'the',
#   'site',
#   '.Their',
#   '<END>'],
#  ['<START>',
#   'mother',
#   ',',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   'was',
#   'from',
#   '<UNKOWN>',
#   'in',
#   'East',
#   '<UNKOWN>',
#   ',',
#   'and',
#   'their',
#   'father',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'was',
#   'a',
#   '<UNKOWN>',
#   'of',
#   '<UNKOWN>',
#   ',',
#   'now',
#   'part',
#   'of',
#   'France',
#   ',',
#   'and',
#   'worked',
#   'as',
#   'a',
#   '<UNKOWN>',
#   '.In',
#   '<END>'],
#  ['<START>',
#   '2002',
#   ',',
#   'he',
#   'began',
#   'work',
#   'on',
#   'a',
#   'series',
#   'of',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'for',
#   'the',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'to',
#   'record',
#   'on',
#   'the',
#   '<UNKOWN>',
#   'record',
#   'label',
#   '.Belgium',
#   'relied',
#   'heavily',
#   'on',
#   'free',
#   '<UNKOWN>',
#   'economic',
#   'policies',
#   'after',
#   'its',
#   '<UNKOWN>',
#   'in',
#   '<UNKOWN>',
#   ',',
#   'and',
#   'had',
#   'the',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '.',
#   '<END>'],
#  ['<START>',
#   'It',
#   'also',
#   'did',
#   'not',
#   'have',
#   'the',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'and',
#   'food',
#   '<UNKOWN>',
#   'seen',
#   'in',
#   'the',
#   '<UNKOWN>',
#   'of',
#   '<UNKOWN>',
#   'Europe',
#   '<UNKOWN>',
#   'from',
#   '<UNKOWN>',
#   'College',
#   ',',
#   '<UNKOWN>',
#   'University',
#   'in',
#   '<UNKOWN>',
#   'and',
#   '<UNKOWN>',
#   '.Because',
#   'the',
#   '<UNKOWN>',
#   'is',
#   'known',
#   ',',
#   'it',
#   'is',
#   'no',
#   'longer',
#   'a',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'was',
#   'a',
#   'car',
#   'produced',
#   'by',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'Company',
#   'from',
#   '<UNKOWN>',
#   'through',
#   '<UNKOWN>',
#   '.The',
#   'change',
#   'is',
#   'due',
#   'to',
#   '<UNKOWN>',
#   'of',
#   'the',
#   '<UNKOWN>',
#   '.In',
#   '<END>'],
#  ['<START>',
#   'some',
#   '<UNKOWN>',
#   ',',
#   'including',
#   'China',
#   ',',
#   'lettuce',
#   'is',
#   'eaten',
#   '<UNKOWN>',
#   '.It',
#   'is',
#   'also',
#   'a',
#   'starting',
#   'point',
#   'for',
#   'people',
#   '<UNKOWN>',
#   'to',
#   'see',
#   '<UNKOWN>',
#   ',',
#   'Cape',
#   'York',
#   'Peninsula',
#   ',',
#   'and',
#   'the',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '.It',
#   'is',
#   '<UNKOWN>',
#   'on',
#   ',',
#   'near',
#   'New',
#   'Zealand',
#   '.In',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'he',
#   'founded',
#   'the',
#   '``',
#   '<UNKOWN>',
#   "''",
#   'Armenian',
#   'pop',
#   '-',
#   'rock',
#   'band',
#   ',',
#   'the',
#   '<UNKOWN>',
#   'of',
#   '``',
#   'Song',
#   '-',
#   '<UNKOWN>',
#   "''",
#   'festival',
#   '.The',
#   '<END>'],
#  ['<START>',
#   'family',
#   'is',
#   '<UNKOWN>',
#   'distributed',
#   'around',
#   'the',
#   '<UNKOWN>',
#   ',',
#   'where',
#   'those',
#   'with',
#   'edible',
#   '<UNKOWN>',
#   'were',
#   '<UNKOWN>',
#   'the',
#   'earliest',
#   '<UNKOWN>',
#   'plants',
#   'in',
#   'both',
#   'the',
#   'Old',
#   'and',
#   'New',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'tea',
#   'is',
#   'a',
#   'kind',
#   'of',
#   'tea',
#   'that',
#   'has',
#   'a',
#   'flavor',
#   'and',
#   '<UNKOWN>',
#   'that',
#   'comes',
#   '<UNKOWN>',
#   'orange',
#   ',',
#   'a',
#   '<UNKOWN>',
#   'fruit',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'is',
#   'an',
#   'Australian',
#   'Formula',
#   'One',
#   '<UNKOWN>',
#   '.If',
#   '<END>'],
#  ['<START>',
#   'a',
#   'and',
#   'd',
#   'are',
#   'natural',
#   'numbers',
#   ',',
#   'with',
#   'd',
#   'non',
#   '-',
#   '<UNKOWN>',
#   ',',
#   'it',
#   'can',
#   'be',
#   'proved',
#   'that',
#   'there',
#   'exist',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'q',
#   'and',
#   'r',
#   ',',
#   'such',
#   'that',
#   'a',
#   '=',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'r',
#   'and',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>', 'r', '<UNKOWN>', '<UNKOWN>', '<END>'],
#  ['<START>',
#   'The',
#   'number',
#   'q',
#   'is',
#   'called',
#   'the',
#   '<UNKOWN>',
#   ',',
#   'while',
#   'r',
#   'is',
#   'called',
#   'the',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   '.It',
#   'has',
#   '11',
#   'cantons',
#   'and',
#   '<UNKOWN>',
#   'communes',
#   '.In',
#   '<END>'],
#  ['<START>',
#   'the',
#   'days',
#   'leading',
#   'up',
#   'to',
#   'birth',
#   'the',
#   'female',
#   'can',
#   'often',
#   'be',
#   'seen',
#   '<UNKOWN>',
#   'in',
#   'the',
#   'sun',
#   'on',
#   'a',
#   'warm',
#   '<UNKOWN>',
#   '.Michael',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'is',
#   'an',
#   'American',
#   'actor',
#   'who',
#   'has',
#   'starred',
#   'in',
#   'numerous',
#   '<UNKOWN>',
#   'and',
#   'has',
#   'been',
#   'a',
#   '<UNKOWN>',
#   'on',
#   'numerous',
#   'television',
#   'shows',
#   'including',
#   ':',
#   '<UNKOWN>',
#   'and',
#   'a',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   'The',
#   '<UNKOWN>',
#   'Life',
#   'of',
#   '<UNKOWN>',
#   'and',
#   '<UNKOWN>',
#   ',',
#   'and',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '-',
#   '<UNKOWN>',
#   'brought',
#   'many',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'from',
#   'many',
#   'countries',
#   ',',
#   'especially',
#   'Japan',
#   '.The',
#   '<UNKOWN>',
#   'church',
#   ',',
#   '<UNKOWN>',
#   'since',
#   'the',
#   '1970s',
#   ',',
#   'is',
#   'on',
#   'the',
#   'site',
#   'of',
#   'an',
#   'early',
#   'Christian',
#   'monastery',
#   'founded',
#   'by',
#   'St.',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   'of',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   'the',
#   'server',
#   'with',
#   'a',
#   '<UNKOWN>',
#   'to',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'in',
#   '<UNKOWN>',
#   'to',
#   'a',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'at',
#   'the',
#   'user',
#   ',',
#   'but',
#   'not',
#   'to',
#   'a',
#   'channel',
#   'they',
#   'are',
#   'on',
#   '.When',
#   '<END>'],
#  ['<START>',
#   'Texas',
#   'became',
#   'the',
#   '<UNKOWN>',
#   'state',
#   'of',
#   'the',
#   'United',
#   'States',
#   'of',
#   'America',
#   'on',
#   'December',
#   '29',
#   ',',
#   '<UNKOWN>',
#   ',',
#   'its',
#   'national',
#   'flag',
#   'became',
#   'the',
#   'state',
#   'flag',
#   '.',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'color',
#   'means',
#   'a',
#   'special',
#   'symbol',
#   'on',
#   'the',
#   'flag',
#   ':',
#   'blue',
#   '<UNKOWN>',
#   'for',
#   'loyalty',
#   ',',
#   'white',
#   'for',
#   '<UNKOWN>',
#   ',',
#   'and',
#   'red',
#   'for',
#   '<UNKOWN>',
#   '.After',
#   '<END>'],
#  ['<START>',
#   'the',
#   '<UNKOWN>',
#   'season',
#   ',',
#   'Switzer',
#   'became',
#   'an',
#   '<UNKOWN>',
#   'coach',
#   'at',
#   'the',
#   'University',
#   'of',
#   'Oklahoma',
#   '.',
#   '<END>'],
#  ['<START>',
#   'He',
#   'became',
#   'head',
#   'coach',
#   'there',
#   'in',
#   '<UNKOWN>',
#   '.The',
#   '<END>'],
#  ['<START>',
#   'Book',
#   'of',
#   'Baruch',
#   ',',
#   'sometimes',
#   'called',
#   '1',
#   'Baruch',
#   ',',
#   'is',
#   'a',
#   '<UNKOWN>',
#   'or',
#   '<UNKOWN>',
#   'book',
#   'of',
#   'the',
#   'Bible',
#   '.As',
#   'of',
#   'the',
#   '2000',
#   'census',
#   ',',
#   'the',
#   'population',
#   'of',
#   'the',
#   'city',
#   'is',
#   '<UNKOWN>',
#   '.In',
#   '<END>'],
#  ['<START>',
#   'the',
#   'next',
#   '<UNKOWN>',
#   ',',
#   'the',
#   'outcasts',
#   'tribe',
#   'won',
#   'against',
#   'Morgan',
#   'and',
#   'Drake',
#   ';',
#   'both',
#   'would',
#   'have',
#   'to',
#   'vote',
#   'off',
#   'a',
#   'player',
#   'at',
#   'separate',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   'while',
#   'the',
#   'outcasts',
#   'tribe',
#   'would',
#   'vote',
#   'in',
#   'two',
#   'players',
#   'to',
#   'return',
#   'to',
#   'the',
#   'game',
#   'in',
#   'their',
#   'place',
#   '<UNKOWN>',
#   'is',
#   'also',
#   'known',
#   'because',
#   'of',
#   'the',
#   'big',
#   '<UNKOWN>',
#   'in',
#   '1986',
#   '.After',
#   '<END>'],
#  ['<START>',
#   'that',
#   'she',
#   '<UNKOWN>',
#   'in',
#   'the',
#   'TV',
#   'series',
#   '90',
#   '-',
#   '<UNKOWN>',
#   '-',
#   '90',
#   '<UNKOWN>',
#   'and',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>', 'y', '<UNKOWN>', '.The', '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'was',
#   'a',
#   'traditional',
#   'place',
#   'for',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   'and',
#   'had',
#   'a',
#   'lot',
#   'of',
#   'small',
#   '<UNKOWN>',
#   'for',
#   'the',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   'can',
#   'then',
#   'be',
#   'de',
#   '-',
#   '<UNKOWN>',
#   ',',
#   'de',
#   '-',
#   '<UNKOWN>',
#   ',',
#   'and',
#   'ground',
#   'with',
#   'a',
#   '<UNKOWN>',
#   'until',
#   'it',
#   '<UNKOWN>',
#   'the',
#   '<UNKOWN>',
#   ',',
#   'bright',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   '-',
#   'like',
#   '<UNKOWN>',
#   'known',
#   'as',
#   '<UNKOWN>',
#   '.The',
#   'prize',
#   'is',
#   'named',
#   'for',
#   '<UNKOWN>',
#   '-',
#   'Louis',
#   '<UNKOWN>',
#   '.While',
#   'the',
#   'first',
#   'movie',
#   '<UNKOWN>',
#   'with',
#   '<UNKOWN>',
#   "'s",
#   '<UNKOWN>',
#   'with',
#   '<UNKOWN>',
#   ',',
#   'this',
#   'one',
#   '<UNKOWN>',
#   'more',
#   'on',
#   'his',
#   '<UNKOWN>',
#   'with',
#   'a',
#   'young',
#   'human',
#   ',',
#   '<UNKOWN>',
#   '.These',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'are',
#   'present',
#   'even',
#   'if',
#   'the',
#   '<UNKOWN>',
#   'data',
#   'are',
#   'written',
#   'to',
#   'the',
#   'buffer',
#   'once',
#   'and',
#   'read',
#   'from',
#   'the',
#   'buffer',
#   'once',
#   '.The',
#   '<END>'],
#  ['<START>',
#   'county',
#   'administration',
#   'is',
#   'in',
#   '<UNKOWN>',
#   ',',
#   'which',
#   'is',
#   'not',
#   'part',
#   'of',
#   'the',
#   'county',
#   '.His',
#   '<END>'],
#  ['<START>',
#   'parents',
#   ',',
#   '<UNKOWN>',
#   'Adams',
#   '<UNKOWN>',
#   '.',
#   'and',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   'came',
#   'from',
#   'strong',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '.Sometimes',
#   '<END>'],
#  ['<START>',
#   'it',
#   'can',
#   'best',
#   'be',
#   '<UNKOWN>',
#   'by',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   'using',
#   'computers',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   ',',
#   'Pas',
#   '-',
#   'de',
#   '-',
#   'Calais',
#   'is',
#   'a',
#   'commune',
#   '.',
#   '<END>'],
#  ['<START>',
#   'It',
#   'is',
#   'found',
#   'in',
#   'the',
#   'region',
#   'Nord',
#   '-',
#   'Pas',
#   '-',
#   'de',
#   '-',
#   'Calais',
#   'in',
#   'the',
#   'Pas',
#   '-',
#   'de',
#   '-',
#   'Calais',
#   'department',
#   'in',
#   'the',
#   'north',
#   'of',
#   'France',
#   '.It',
#   'can',
#   'be',
#   'used',
#   'at',
#   'the',
#   'end',
#   'of',
#   'the',
#   'article',
#   ',',
#   '<UNKOWN>',
#   'in',
#   'the',
#   '<UNKOWN>',
#   'section',
#   '.Before',
#   '<UNKOWN>',
#   'with',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   'modeled',
#   'for',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   "'s",
#   '``',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '/',
#   'W',
#   '<UNKOWN>',
#   '-',
#   '<UNKOWN>',
#   "''",
#   'in',
#   'March',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   'Cuba',
#   ',',
#   'and',
#   'hit',
#   'south',
#   'Florida',
#   'beginning',
#   'late',
#   'on',
#   'August',
#   '18',
#   ',',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'across',
#   'the',
#   'peninsula',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   'years',
#   'later',
#   ',',
#   'Fey',
#   'became',
#   'a',
#   '<UNKOWN>',
#   'for',
#   'the',
#   '<UNKOWN>',
#   'comedy',
#   'show',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'this',
#   'festival',
#   'because',
#   'of',
#   'the',
#   '<UNKOWN>',
#   'of',
#   'their',
#   '<UNKOWN>',
#   'Guru',
#   ',',
#   'Guru',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   'from',
#   'the',
#   '<UNKOWN>',
#   'Fort',
#   ',',
#   'where',
#   'he',
#   'had',
#   'been',
#   '<UNKOWN>',
#   'along',
#   'with',
#   '53',
#   'other',
#   'Kings',
#   'by',
#   'Emperor',
#   '<UNKOWN>',
#   ',',
#   'and',
#   'all',
#   'of',
#   'those',
#   '53',
#   'Kings',
#   'had',
#   'been',
#   '<UNKOWN>',
#   'along',
#   'with',
#   'the',
#   'Guru',
#   'on',
#   'the',
#   'Guru',
#   "'s",
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'was',
#   '<UNKOWN>',
#   'during',
#   'the',
#   'pre',
#   '-',
#   'game',
#   'warm',
#   'up',
#   'and',
#   '<UNKOWN>',
#   'was',
#   'started',
#   'instead',
#   '<UNKOWN>',
#   'of',
#   'up',
#   'to',
#   '<UNKOWN>',
#   'mph',
#   '<UNKOWN>',
#   'Northern',
#   'Ireland',
#   'during',
#   'the',
#   'night',
#   'of',
#   'the',
#   '<UNKOWN>',
#   '&',
#   '<UNKOWN>',
#   '.He',
#   'is',
#   'well',
#   '-',
#   'known',
#   'for',
#   'playing',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'in',
#   '<UNKOWN>',
#   'Jackson',
#   "'s",
#   'film',
#   '<UNKOWN>',
#   'of',
#   'J.',
#   'R.',
#   'R.',
#   '<UNKOWN>',
#   "'s",
#   'The',
#   'Lord',
#   'of',
#   'the',
#   '<UNKOWN>',
#   '.',
#   '<END>'],
#  ['<START>',
#   'He',
#   'is',
#   'also',
#   'well',
#   '-',
#   'known',
#   'for',
#   'playing',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'on',
#   'the',
#   'television',
#   'show',
#   '<UNKOWN>',
#   '.They',
#   '<UNKOWN>',
#   'to',
#   'have',
#   '<UNKOWN>',
#   ',',
#   'and',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '.It',
#   'is',
#   'situated',
#   '20',
#   'km',
#   'southwest',
#   'of',
#   '<UNKOWN>',
#   'an',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   'and',
#   '19',
#   'km',
#   'north',
#   'of',
#   'Ravensburg',
#   '.It',
#   'is',
#   'the',
#   'location',
#   'of',
#   'the',
#   'Royal',
#   'Observatory',
#   'of',
#   'London',
#   'that',
#   'is',
#   'the',
#   'basis',
#   'for',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'Time',
#   'and',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'Time',
#   '<UNKOWN>',
#   '-',
#   'de',
#   '-',
#   '<UNKOWN>',
#   'is',
#   'a',
#   'commune',
#   'of',
#   'the',
#   'Pyrénées',
#   '-',
#   'Atlantiques',
#   'département',
#   'in',
#   'the',
#   'southwestern',
#   'part',
#   'of',
#   'France',
#   '<END>'],
#  ['<START>',
#   '.It',
#   'is',
#   'named',
#   'in',
#   'honor',
#   'of',
#   'the',
#   'physicist',
#   'William',
#   '<UNKOWN>',
#   ',',
#   'the',
#   'first',
#   'Lord',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'wrote',
#   'his',
#   'famous',
#   '<UNKOWN>',
#   'originally',
#   'for',
#   'a',
#   'young',
#   'singer',
#   ',',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   'when',
#   'she',
#   'gave',
#   'birth',
#   'to',
#   'her',
#   'second',
#   'son',
#   '<UNKOWN>',
#   '70',
#   'is',
#   'an',
#   '<UNKOWN>',
#   'Highway',
#   'in',
#   'the',
#   'United',
#   'States',
#   '.',
#   '<END>'],
#  ['<START>',
#   'It',
#   'goes',
#   'from',
#   '<UNKOWN>',
#   'Fort',
#   ',',
#   'Utah',
#   'east',
#   'to',
#   '<UNKOWN>',
#   ',',
#   'Maryland',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'is',
#   'a',
#   'Spanish',
#   'football',
#   'player',
#   '.',
#   '<END>'],
#  ['<START>',
#   'He',
#   'plays',
#   'for',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'from',
#   'the',
#   'use',
#   'in',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'was',
#   'also',
#   'used',
#   'to',
#   'make',
#   '<UNKOWN>',
#   '.This',
#   'is',
#   'a',
#   '<UNKOWN>',
#   'template',
#   'for',
#   'various',
#   '<UNKOWN>',
#   'from',
#   'the',
#   'series',
#   ',',
#   'not',
#   '<UNKOWN>',
#   'to',
#   'be',
#   'used',
#   'on',
#   'its',
#   'own',
#   '.The',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'has',
#   'a',
#   '<UNKOWN>',
#   'showing',
#   'one',
#   'of',
#   'the',
#   'state',
#   "'s",
#   'most',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '-',
#   'its',
#   'major',
#   'rivers',
#   '.Every',
#   '<END>'],
#  ['<START>',
#   'match',
#   'on',
#   'the',
#   'card',
#   'was',
#   '<UNKOWN>',
#   'for',
#   'a',
#   'championship',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'was',
#   'elected',
#   'to',
#   'the',
#   '<UNKOWN>',
#   'Senate',
#   'in',
#   '1994',
#   ',',
#   'that',
#   'made',
#   'her',
#   'the',
#   'first',
#   'woman',
#   'in',
#   'the',
#   'United',
#   'States',
#   "'s",
#   'history',
#   'in',
#   'both',
#   'houses',
#   'of',
#   'the',
#   'state',
#   'legislature',
#   'and',
#   'both',
#   'houses',
#   'of',
#   'the',
#   'Congress',
#   ',',
#   'and',
#   'the',
#   'second',
#   'woman',
#   'Senator',
#   'in',
#   'history',
#   'to',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '.',
#   '<END>'],
#  ['<START>',
#   'She',
#   'is',
#   'the',
#   'first',
#   'Greek',
#   'woman',
#   'ever',
#   'elected',
#   'to',
#   'Congress',
#   '.It',
#   'was',
#   'produced',
#   'by',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'and',
#   'was',
#   'released',
#   'on',
#   'November',
#   '7',
#   ',',
#   '2008',
#   '.She',
#   'left',
#   'school',
#   'age',
#   '16',
#   'and',
#   '<UNKOWN>',
#   'as',
#   'a',
#   'piano',
#   '<UNKOWN>',
#   '.From',
#   '<END>'],
#  ['<START>',
#   'to',
#   '<UNKOWN>',
#   ',',
#   'the',
#   'games',
#   'were',
#   'held',
#   'as',
#   'a',
#   '<UNKOWN>',
#   'tournament',
#   'within',
#   'the',
#   '<UNKOWN>',
#   '.In',
#   '<END>'],
#  ['<START>',
#   '1998',
#   ',',
#   '<UNKOWN>',
#   'made',
#   'a',
#   'commercial',
#   'for',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '2',
#   '.Robert',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'is',
#   'a',
#   'former',
#   'Croatian',
#   'football',
#   'player',
#   '<UNKOWN>',
#   'to',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   "'s",
#   '2007',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   'it',
#   'held',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'at',
#   '$',
#   '<UNKOWN>',
#   '/',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'blue',
#   'or',
#   '<UNKOWN>',
#   'is',
#   'a',
#   'dark',
#   '<UNKOWN>',
#   'of',
#   'the',
#   'color',
#   'blue',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'the',
#   '<UNKOWN>',
#   'of',
#   'the',
#   'warlock',
#   'and',
#   'sees',
#   'that',
#   'the',
#   'heart',
#   '<UNKOWN>',
#   'to',
#   'the',
#   'warlock',
#   '.One',
#   'type',
#   'of',
#   'shoe',
#   'is',
#   '<UNKOWN>',
#   '.',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'main',
#   'purpose',
#   'is',
#   'to',
#   'make',
#   'running',
#   ',',
#   'walking',
#   ',',
#   'or',
#   '<UNKOWN>',
#   'easier',
#   'by',
#   'making',
#   'the',
#   '<UNKOWN>',
#   'of',
#   'the',
#   'shoe',
#   '<UNKOWN>',
#   'and',
#   'the',
#   '<UNKOWN>',
#   'of',
#   'the',
#   'shoe',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'is',
#   'an',
#   'American',
#   'songwriter',
#   'and',
#   'singer',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'were',
#   'usually',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '.The',
#   '<END>'],
#  ['<START>',
#   'British',
#   'Rail',
#   'Class',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'multiple',
#   'units',
#   'were',
#   'built',
#   'by',
#   '<UNKOWN>',
#   'at',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'from',
#   '2000',
#   '-',
#   '01',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'of',
#   '<UNKOWN>',
#   'and',
#   'Westminster',
#   '<UNKOWN>',
#   'are',
#   'in',
#   'Westminster',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   'within',
#   'a',
#   'page',
#   'should',
#   'use',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'has',
#   'been',
#   'in',
#   '<UNKOWN>',
#   'for',
#   'the',
#   'game',
#   '<UNKOWN>',
#   ',',
#   'the',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   "'s",
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   'and',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   "'s",
#   '``',
#   '<UNKOWN>',
#   "''",
#   '<UNKOWN>',
#   '.The',
#   'Roman',
#   '<UNKOWN>',
#   'consists',
#   'of',
#   'the',
#   '<UNKOWN>',
#   'of',
#   'State',
#   ',',
#   'nine',
#   '<UNKOWN>',
#   ',',
#   'three',
#   '<UNKOWN>',
#   ',',
#   '11',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   'and',
#   'a',
#   'complex',
#   'of',
#   'offices',
#   'that',
#   '<UNKOWN>',
#   'church',
#   '<UNKOWN>',
#   'at',
#   'the',
#   'highest',
#   'level',
#   '<UNKOWN>',
#   'waves',
#   'in',
#   'the',
#   'Atlantic',
#   'Ocean',
#   'form',
#   'from',
#   '<UNKOWN>',
#   'which',
#   '<UNKOWN>',
#   'off',
#   'the',
#   '<UNKOWN>',
#   'of',
#   'Africa',
#   '<UNKOWN>',
#   'the',
#   'Atlantic',
#   'Ocean',
#   '<UNKOWN>',
#   'is',
#   'a',
#   'commune',
#   'of',
#   'the',
#   'Aube',
#   'département',
#   'in',
#   'the',
#   'north',
#   '-',
#   'central',
#   'part',
#   'of',
#   'France',
#   '.White',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'often',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'and',
#   'Australian',
#   '<UNKOWN>',
#   'as',
#   '<UNKOWN>',
#   'to',
#   '<UNKOWN>',
#   ',',
#   'rather',
#   'than',
#   'as',
#   '<UNKOWN>',
#   'in',
#   'their',
#   'own',
#   '<UNKOWN>',
#   '.The',
#   'religion',
#   '<UNKOWN>',
#   'in',
#   'the',
#   'city',
#   'of',
#   '<UNKOWN>',
#   ',',
#   'the',
#   'capital',
#   'of',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   'Dolj',
#   'is',
#   'a',
#   'commune',
#   'found',
#   'in',
#   'Dolj',
#   'County',
#   ',',
#   'Romania',
#   '.It',
#   'is',
#   'the',
#   'county',
#   'seat',
#   'of',
#   'Pope',
#   'County',
#   '.The',
#   '<END>'],
#  ['<START>',
#   'confidence',
#   '<UNKOWN>',
#   'is',
#   'always',
#   'given',
#   'together',
#   'with',
#   'the',
#   'confidence',
#   'level',
#   '.As',
#   '<END>'],
#  ['<START>',
#   'a',
#   'young',
#   'man',
#   ',',
#   '<UNKOWN>',
#   'found',
#   'a',
#   'job',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'in',
#   'Hungary',
#   '<UNKOWN>',
#   'is',
#   'like',
#   'Niobe',
#   'in',
#   'that',
#   'he',
#   'is',
#   '<UNKOWN>',
#   'for',
#   'his',
#   'son',
#   '<UNKOWN>',
#   ',',
#   'who',
#   'was',
#   '<UNKOWN>',
#   'and',
#   'not',
#   'buried',
#   'for',
#   'several',
#   'days',
#   '.',
#   '<END>'],
#  ['<START>',
#   'Niobe',
#   'is',
#   'also',
#   '<UNKOWN>',
#   'in',
#   '<UNKOWN>',
#   "'",
#   'Antigone',
#   ':',
#   'as',
#   'she',
#   'is',
#   '<UNKOWN>',
#   'toward',
#   'her',
#   'death',
#   ',',
#   'Antigone',
#   '<UNKOWN>',
#   'her',
#   'own',
#   '<UNKOWN>',
#   'to',
#   'that',
#   'of',
#   'Niobe',
#   '<UNKOWN>',
#   'is',
#   'the',
#   '<UNKOWN>',
#   'of',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'to',
#   'some',
#   '<UNKOWN>',
#   '.La',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   '-',
#   'sur',
#   '-',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'is',
#   'a',
#   'commune',
#   '.',
#   '<END>'],
#  ['<START>',
#   'It',
#   'is',
#   'found',
#   'in',
#   'the',
#   'region',
#   'Picardie',
#   'in',
#   'the',
#   'Aisne',
#   'department',
#   'in',
#   'the',
#   'north',
#   'of',
#   'France',
#   '.Although',
#   '<END>'],
#  ['<START>',
#   'he',
#   'considered',
#   'himself',
#   'a',
#   'painter',
#   'of',
#   'history',
#   'in',
#   'the',
#   'tradition',
#   'of',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'and',
#   'Jacques',
#   '-',
#   'Louis',
#   'David',
#   ',',
#   'by',
#   'the',
#   'end',
#   'of',
#   'his',
#   'life',
#   'it',
#   'was',
#   '<UNKOWN>',
#   "'s",
#   '<UNKOWN>',
#   ',',
#   'both',
#   'painted',
#   'and',
#   '<UNKOWN>',
#   ',',
#   'that',
#   'were',
#   '<UNKOWN>',
#   'as',
#   'his',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   'media',
#   'like',
#   'digital',
#   'audio',
#   ',',
#   'digital',
#   'video',
#   'and',
#   'other',
#   'digital',
#   '``',
#   'content',
#   "''",
#   'can',
#   'be',
#   'created',
#   ',',
#   'referred',
#   'to',
#   'and',
#   'distributed',
#   'by',
#   'digital',
#   'information',
#   '<UNKOWN>',
#   'machines',
#   '.',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'media',
#   'is',
#   'a',
#   'big',
#   'change',
#   'from',
#   'media',
#   '.The',
#   '<END>'],
#  ['<START>',
#   'most',
#   'famous',
#   'example',
#   'of',
#   'a',
#   '<UNKOWN>',
#   'of',
#   'this',
#   'type',
#   'is',
#   'the',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   '-',
#   '<UNKOWN>',
#   'is',
#   'a',
#   'commune',
#   'of',
#   'the',
#   'Pyrénées',
#   '-',
#   'Atlantiques',
#   'département',
#   'in',
#   'the',
#   'southwestern',
#   'part',
#   'of',
#   'France',
#   '.It',
#   'is',
#   'the',
#   'natural',
#   'number',
#   'after',
#   'One',
#   'and',
#   'before',
#   '<UNKOWN>',
#   '.The',
#   'city',
#   'was',
#   'named',
#   'after',
#   'Juan',
#   'Ponce',
#   'de',
#   'León',
#   'y',
#   '<UNKOWN>',
#   ',',
#   'the',
#   '<UNKOWN>',
#   'of',
#   'Spanish',
#   '<UNKOWN>',
#   'Juan',
#   'Ponce',
#   'de',
#   'León',
#   '.It',
#   'is',
#   'on',
#   'the',
#   'eastern',
#   'border',
#   'of',
#   'France',
#   '.',
#   '<END>'],
#  ['<START>',
#   'It',
#   'lies',
#   'on',
#   'the',
#   'west',
#   '<UNKOWN>',
#   'of',
#   'the',
#   '<UNKOWN>',
#   'Rhine',
#   ',',
#   'next',
#   'to',
#   'Germany',
#   'and',
#   'Switzerland',
#   '<UNKOWN>',
#   'is',
#   'a',
#   'large',
#   '<UNKOWN>',
#   'that',
#   'lives',
#   'in',
#   'South',
#   'and',
#   'Central',
#   'America',
#   '.It',
#   'is',
#   'a',
#   '<UNKOWN>',
#   'to',
#   'the',
#   '1996',
#   'movie',
#   '<UNKOWN>',
#   'Dalmatians',
#   ',',
#   'which',
#   'was',
#   'a',
#   'live',
#   '-',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'of',
#   'the',
#   '1961',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'movie',
#   'One',
#   '<UNKOWN>',
#   'and',
#   'One',
#   'Dalmatians',
#   '.The',
#   '<END>'],
#  ['<START>', 'Sheppard', '<UNKOWN>', '<UNKOWN>', '.', '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'was',
#   'immediately',
#   '<UNKOWN>',
#   'with',
#   'an',
#   'August',
#   '6',
#   '2000',
#   'observation',
#   'by',
#   'the',
#   'team',
#   'of',
#   '<UNKOWN>',
#   'J.',
#   '<UNKOWN>',
#   ',',
#   'John',
#   'J.',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   '-',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   'J.',
#   '<UNKOWN>',
#   ',',
#   'Brian',
#   'G.',
#   'Marsden',
#   ',',
#   '<UNKOWN>',
#   'D.',
#   '<UNKOWN>',
#   'and',
#   'Joseph',
#   'A.',
#   '<UNKOWN>',
#   '-',
#   'an',
#   'observation',
#   'that',
#   'was',
#   'reported',
#   'to',
#   'the',
#   'Minor',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'but',
#   'not',
#   'published',
#   'as',
#   'an',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   '1995',
#   ',',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'for',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'and',
#   'Transport',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'is',
#   'a',
#   'former',
#   '<UNKOWN>',
#   'football',
#   'player',
#   '.It',
#   'is',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'to',
#   '<UNKOWN>',
#   'our',
#   'contact',
#   '<UNKOWN>',
#   'asking',
#   'for',
#   '<UNKOWN>',
#   'to',
#   '<UNKOWN>',
#   'articles',
#   'or',
#   'images',
#   ',',
#   'even',
#   'if',
#   'the',
#   'rules',
#   'of',
#   'operation',
#   'of',
#   'your',
#   'company',
#   'or',
#   'school',
#   '<UNKOWN>',
#   'that',
#   'you',
#   '<UNKOWN>',
#   'web',
#   'site',
#   '<UNKOWN>',
#   'before',
#   '<UNKOWN>',
#   'their',
#   'content',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'of',
#   '<UNKOWN>',
#   'life',
#   '-',
#   '<UNKOWN>',
#   ',',
#   'and',
#   '<UNKOWN>',
#   'are',
#   'found',
#   'here',
#   '.The',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'were',
#   'pressure',
#   '-',
#   '<UNKOWN>',
#   'but',
#   'the',
#   '<UNKOWN>',
#   'proved',
#   'to',
#   'be',
#   '<UNKOWN>',
#   '.The',
#   '<END>'],
#  ['<START>',
#   'British',
#   'Rail',
#   'Class',
#   '<UNKOWN>',
#   'diesel',
#   '-',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'were',
#   'built',
#   'by',
#   'the',
#   'North',
#   'British',
#   '<UNKOWN>',
#   'Company',
#   'from',
#   '1960',
#   '-',
#   '1962',
#   '.It',
#   'was',
#   'so',
#   'successful',
#   'that',
#   'from',
#   'the',
#   'Ming',
#   'dynasty',
#   'onwards',
#   ',',
#   'a',
#   'lot',
#   'of',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   'the',
#   'most',
#   'famous',
#   'and',
#   '<UNKOWN>',
#   'being',
#   '``',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   "''",
#   '<UNKOWN>',
#   'by',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   'the',
#   '17th',
#   'son',
#   'of',
#   'the',
#   '<UNKOWN>',
#   'of',
#   'the',
#   'Ming',
#   'dynasty',
#   '.In',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   'won',
#   'the',
#   '2002',
#   'Australian',
#   '<UNKOWN>',
#   'with',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '.When',
#   '<END>'],
#  ['<START>',
#   'Tropical',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'became',
#   'Tropical',
#   'Luis',
#   'on',
#   'August',
#   '29',
#   ',',
#   'it',
#   '<UNKOWN>',
#   'the',
#   'earliest',
#   'date',
#   'of',
#   'a',
#   'seasons',
#   '<UNKOWN>',
#   'named',
#   'storm',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'divides',
#   'by',
#   '100,000',
#   'then',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'back',
#   'on',
#   '.A',
#   '<END>'],
#  ['<START>',
#   'person',
#   'who',
#   '<UNKOWN>',
#   'sexual',
#   '<UNKOWN>',
#   'is',
#   'called',
#   'a',
#   '<UNKOWN>',
#   ',',
#   'abuser',
#   ',',
#   'or',
#   'sexual',
#   'abuser',
#   '.Saint',
#   '<END>'],
#  ['<START>',
#   'Martin',
#   'is',
#   'a',
#   'tropical',
#   'island',
#   'in',
#   'the',
#   'northeast',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   '300',
#   'km',
#   'southeast',
#   'of',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'is',
#   'a',
#   'commune',
#   '.',
#   '<END>'],
#  ['<START>',
#   'It',
#   'is',
#   'found',
#   'in',
#   'the',
#   'region',
#   'Aquitaine',
#   'in',
#   'the',
#   'Gironde',
#   'department',
#   'in',
#   'the',
#   'southwest',
#   'of',
#   'France',
#   '.He',
#   'also',
#   'won',
#   '<END>'],
#  ['<START>',
#   'multiple',
#   'European',
#   'and',
#   'World',
#   '<UNKOWN>',
#   'championships',
#   '.His',
#   '<END>'],
#  ['<START>',
#   'father',
#   'was',
#   'a',
#   '<UNKOWN>',
#   'heart',
#   '<UNKOWN>',
#   'from',
#   'Scotland',
#   ',',
#   'and',
#   'his',
#   'mother',
#   'the',
#   'French',
#   'Catholic',
#   'daughter',
#   'of',
#   'an',
#   'army',
#   '<UNKOWN>',
#   '.On',
#   'some',
#   'days',
#   'the',
#   'Canadian',
#   'government',
#   '<UNKOWN>',
#   'the',
#   'Royal',
#   'Union',
#   'Flag',
#   'next',
#   'to',
#   'the',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'Flag',
#   '.',
#   '<END>'],
#  ['<START>',
#   'The',
#   'Royal',
#   'Union',
#   'Flag',
#   'is',
#   'the',
#   'British',
#   'Union',
#   'Jack',
#   ',',
#   'and',
#   'is',
#   'a',
#   'symbol',
#   'that',
#   'Canada',
#   'is',
#   'a',
#   'member',
#   'of',
#   'the',
#   'Commonwealth',
#   ',',
#   'and',
#   'that',
#   'Canada',
#   'and',
#   'Britain',
#   '<UNKOWN>',
#   'a',
#   'history',
#   'and',
#   'a',
#   '<UNKOWN>',
#   '.When',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'realizes',
#   'it',
#   'is',
#   'his',
#   'own',
#   'son',
#   'he',
#   'must',
#   'kill',
#   ',',
#   'he',
#   'tells',
#   '<UNKOWN>',
#   'to',
#   'go',
#   'away',
#   'and',
#   'never',
#   'see',
#   'him',
#   'again',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>', 'is', 'a', 'commune', '.', '<END>'],
#  ['<START>',
#   'It',
#   'is',
#   'found',
#   'in',
#   'the',
#   'region',
#   'Nord',
#   '-',
#   'Pas',
#   '-',
#   'de',
#   '-',
#   'Calais',
#   'in',
#   'the',
#   'Pas',
#   '-',
#   'de',
#   '-',
#   'Calais',
#   'department',
#   'in',
#   'the',
#   'north',
#   'of',
#   'France',
#   '.A',
#   '<END>'],
#  ['<START>',
#   'real',
#   'or',
#   'complex',
#   'number',
#   'is',
#   'called',
#   '<UNKOWN>',
#   'number',
#   'if',
#   'it',
#   'can',
#   'not',
#   'be',
#   'found',
#   'as',
#   'a',
#   'result',
#   'of',
#   'an',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'with',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '.The',
#   'region',
#   'is',
#   'one',
#   'the',
#   'most',
#   '<UNKOWN>',
#   'in',
#   'the',
#   '<UNKOWN>',
#   '-',
#   '<UNKOWN>',
#   'area',
#   ',',
#   'and',
#   'has',
#   'three',
#   'heavily',
#   '<UNKOWN>',
#   'areas',
#   '-',
#   '<UNKOWN>',
#   'and',
#   'South',
#   '<UNKOWN>',
#   'in',
#   'Georgia',
#   ',',
#   'and',
#   '<UNKOWN>',
#   '-',
#   '<UNKOWN>',
#   'in',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'and',
#   'Danielle',
#   'got',
#   'celebrated',
#   'with',
#   'a',
#   '<UNKOWN>',
#   'the',
#   'next',
#   'day',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   'Sergeant',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'II',
#   'was',
#   'a',
#   'U.S.',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '/',
#   'sniper',
#   '.',
#   '<END>'],
#  ['<START>',
#   'He',
#   'was',
#   'famous',
#   'for',
#   'having',
#   'one',
#   'of',
#   'the',
#   'highest',
#   'numbers',
#   'of',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'in',
#   'the',
#   'U.S.',
#   'military',
#   ',',
#   'during',
#   'the',
#   '<UNKOWN>',
#   'War',
#   ',',
#   'as',
#   'well',
#   'as',
#   '<UNKOWN>',
#   'the',
#   'record',
#   'for',
#   'many',
#   'years',
#   'for',
#   'the',
#   'longest',
#   'sniper',
#   'kill',
#   'in',
#   'history',
#   '.The',
#   '<UNKOWN>',
#   'of',
#   '<UNKOWN>',
#   'is',
#   'higher',
#   'in',
#   'the',
#   'case',
#   'of',
#   'a',
#   'public',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'in',
#   '<UNKOWN>',
#   'built',
#   'a',
#   'car',
#   'called',
#   'the',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '.',
#   '<END>'],
#  ['<START>',
#   'It',
#   'was',
#   'named',
#   'by',
#   'the',
#   'person',
#   'who',
#   'was',
#   '<UNKOWN>',
#   ',',
#   'Kenji',
#   '<UNKOWN>',
#   '.A',
#   '<END>'],
#  ['<START>',
#   'crystal',
#   'radio',
#   ',',
#   'sometimes',
#   'called',
#   'a',
#   'crystal',
#   'set',
#   ',',
#   'is',
#   'a',
#   'very',
#   'simple',
#   '<UNKOWN>',
#   'radio',
#   '<UNKOWN>',
#   ',',
#   'that',
#   'does',
#   'not',
#   'need',
#   '<UNKOWN>',
#   'to',
#   'work',
#   '.The',
#   '<END>'],
#  ['<START>',
#   'following',
#   'parameters',
#   'are',
#   'responsible',
#   'for',
#   'the',
#   'content',
#   'that',
#   'is',
#   '<UNKOWN>',
#   'about',
#   'the',
#   'series',
#   'and',
#   'the',
#   'individual',
#   'games',
#   'within',
#   'the',
#   'series',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'is',
#   'a',
#   'former',
#   'Italian',
#   'football',
#   'player',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   '-',
#   '<UNKOWN>',
#   '&',
#   '<UNKOWN>',
#   'A.',
#   'Black',
#   'Sun',
#   'Empire',
#   '-',
#   'The',
#   '<UNKOWN>',
#   'B.',
#   'Black',
#   'Sun',
#   'Empire',
#   '&',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '-',
#   '<UNKOWN>',
#   'C.',
#   'Black',
#   'Sun',
#   'Empire',
#   '-',
#   '<UNKOWN>',
#   'D.',
#   'Black',
#   'Sun',
#   'Empire',
#   '&',
#   '<UNKOWN>',
#   '-',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'Black',
#   'Sun',
#   'Empire',
#   '&',
#   '<UNKOWN>',
#   '-',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'Black',
#   'Sun',
#   'Empire',
#   '-',
#   '<UNKOWN>',
#   'G.',
#   'Black',
#   'Sun',
#   'Empire',
#   '-',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'H.',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '-',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'of',
#   'expansion',
#   'divided',
#   'by',
#   'the',
#   'change',
#   'in',
#   'temperature',
#   'is',
#   'called',
#   'the',
#   'material',
#   "'s",
#   '<UNKOWN>',
#   'of',
#   '<UNKOWN>',
#   'expansion',
#   'and',
#   'generally',
#   'varies',
#   'with',
#   'temperature',
#   '.Since',
#   '<END>'],
#  ['<START>',
#   'this',
#   'value',
#   'is',
#   'near',
#   'the',
#   'approximate',
#   'diameter',
#   'of',
#   '<UNKOWN>',
#   'itself',
#   ',',
#   'it',
#   'is',
#   'likely',
#   'the',
#   '<UNKOWN>',
#   'body',
#   'was',
#   'not',
#   'heavily',
#   '<UNKOWN>',
#   '.The',
#   '<END>'],
#  ['<START>',
#   'fruit',
#   'is',
#   'a',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'several',
#   'seeds',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'is',
#   'still',
#   'hunting',
#   'for',
#   '<UNKOWN>',
#   ',',
#   'which',
#   '<UNKOWN>',
#   'him',
#   ',',
#   'as',
#   'well',
#   'as',
#   '<UNKOWN>',
#   'and',
#   '<UNKOWN>',
#   ',',
#   'in',
#   '<UNKOWN>',
#   '.The',
#   '<END>'],
#  ['<START>',
#   'Four',
#   'Grand',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   'also',
#   'known',
#   'as',
#   'The',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'was',
#   'an',
#   'administrative',
#   'division',
#   'of',
#   'the',
#   '<UNKOWN>',
#   'Province',
#   'of',
#   'Pakistan',
#   ',',
#   'until',
#   'the',
#   '<UNKOWN>',
#   'of',
#   '2000',
#   '<UNKOWN>',
#   'it',
#   '<UNKOWN>',
#   'beds',
#   'are',
#   'often',
#   'used',
#   'in',
#   'children',
#   "'s",
#   '<UNKOWN>',
#   '.',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'bunk',
#   'beds',
#   'allow',
#   'a',
#   'family',
#   'to',
#   'put',
#   'two',
#   'beds',
#   'in',
#   'the',
#   'space',
#   'of',
#   'a',
#   'single',
#   '<UNKOWN>',
#   ',',
#   'bunk',
#   'beds',
#   'save',
#   'space',
#   '<UNKOWN>',
#   'is',
#   'a',
#   'municipality',
#   'of',
#   'the',
#   'district',
#   '<UNKOWN>',
#   'in',
#   'the',
#   'canton',
#   'of',
#   '<UNKOWN>',
#   'in',
#   'Switzerland',
#   '.When',
#   '<END>'],
#  ['<START>',
#   'the',
#   'first',
#   'Nobel',
#   '<UNKOWN>',
#   'Prize',
#   'was',
#   'awarded',
#   'in',
#   '<UNKOWN>',
#   ',',
#   'the',
#   '<UNKOWN>',
#   'Nobel',
#   'Committee',
#   '<UNKOWN>',
#   'to',
#   'give',
#   'it',
#   'to',
#   'Henry',
#   '<UNKOWN>',
#   'and',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   'a',
#   'leading',
#   '<UNKOWN>',
#   'against',
#   'war',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   'the',
#   '<UNKOWN>',
#   'of',
#   'is',
#   'a',
#   '<UNKOWN>',
#   'of',
#   'the',
#   '<UNKOWN>',
#   'of',
#   ',',
#   'but',
#   'the',
#   'advantage',
#   'is',
#   'that',
#   'the',
#   'template',
#   'code',
#   'is',
#   'much',
#   '<UNKOWN>',
#   '.The',
#   'train',
#   'from',
#   'London',
#   'was',
#   'run',
#   'as',
#   'an',
#   '<UNKOWN>',
#   'train',
#   'on',
#   'the',
#   '<UNKOWN>',
#   'Central',
#   'Line',
#   '<UNKOWN>',
#   '.They',
#   'can',
#   'be',
#   'big',
#   ',',
#   'like',
#   'the',
#   'Grand',
#   'Canyon',
#   ',',
#   'or',
#   'small',
#   '.There',
#   'are',
#   'however',
#   '<UNKOWN>',
#   ',',
#   'including',
#   'the',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'and',
#   'the',
#   '<UNKOWN>',
#   '``',
#   '<UNKOWN>',
#   "''",
#   'or',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '.The',
#   'head',
#   'of',
#   'the',
#   'match',
#   'was',
#   'made',
#   'of',
#   'a',
#   '<UNKOWN>',
#   'of',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   ',',
#   'sugar',
#   ',',
#   'and',
#   '<UNKOWN>',
#   '.The',
#   '<END>'],
#  ['<START>',
#   'party',
#   "'s",
#   'federal',
#   '<UNKOWN>',
#   'leader',
#   'since',
#   '3',
#   'December',
#   '2007',
#   'is',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '.This',
#   '<END>'],
#  ['<START>',
#   'version',
#   'introduced',
#   'support',
#   'for',
#   'the',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'manager',
#   'and',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   'and',
#   'the',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'as',
#   '<UNKOWN>',
#   'tells',
#   'Lulu',
#   'he',
#   '<UNKOWN>',
#   'her',
#   '.',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   'sees',
#   'the',
#   '<UNKOWN>',
#   ',',
#   'and',
#   '<UNKOWN>',
#   'a',
#   'long',
#   'argument',
#   'with',
#   'Lulu',
#   '.The',
#   '<END>'],
#  ['<START>',
#   'Hull',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'is',
#   'where',
#   'the',
#   'River',
#   'Hull',
#   'joins',
#   'the',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'and',
#   'is',
#   '<UNKOWN>',
#   'at',
#   'times',
#   'when',
#   '<UNKOWN>',
#   'high',
#   '<UNKOWN>',
#   'are',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   'is',
#   'a',
#   'county',
#   'in',
#   '<UNKOWN>',
#   ',',
#   'Ireland',
#   '<UNKOWN>',
#   'does',
#   'not',
#   'lead',
#   'a',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'life',
#   'though',
#   'she',
#   'has',
#   'a',
#   'love',
#   'marriage',
#   'with',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'is',
#   'the',
#   'name',
#   'used',
#   'for',
#   'the',
#   'seeds',
#   'of',
#   'several',
#   'plants',
#   '.She',
#   'was',
#   'born',
#   'at',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   ',',
#   'China',
#   'as',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'Bell',
#   ',',
#   'the',
#   'second',
#   'of',
#   'five',
#   'children',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>', '-', 'sur', '-', 'Mer', 'is', 'a', 'commune', '.', '<END>'],
#  ['<START>',
#   'It',
#   'is',
#   'found',
#   'in',
#   'the',
# ...
#   'the',
#   'it',
#   '.',
#   '<END>'],
#  ['<START>',
#   'In',
#   'the',
#   'south',
#   'of',
#   'the',
#   'district',
#   'are',
#   'the',
#   'Austrian',
#   'states',
#   '<UNKOWN>',
#   'and',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'is',
#   'a',
#   'commune',
#   'of',
#   '<UNKOWN>',
#   'people',
#   '.',
#   '<END>'],
#  ['<START>',
#   'It',
#   'is',
#   'found',
#   'in',
#   'the',
#   'region',
#   'Provence',
#   '-',
#   'Alpes',
#   '-',
#   'C',
#   'ôte',
#   "d'Azur",
#   'in',
#   'the',
#   'Bouches',
#   '-',
#   'du',
#   '-',
#   'Rh',
#   'ône',
#   'department',
#   'in',
#   'the',
#   'south',
#   'of',
#   'France',
#   '.Both',
#   '<END>'],
#  ['<START>',
#   'parents',
#   'and',
#   'children',
#   'say',
#   'that',
#   'young',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'pressure',
#   'from',
#   'television',
#   'shows',
#   'and',
#   'other',
#   'children',
#   'to',
#   'look',
#   '<UNKOWN>',
#   'and',
#   '<UNKOWN>',
#   'and',
#   'say',
#   'that',
#   '<UNKOWN>',
#   'pressure',
#   ',',
#   '<UNKOWN>',
#   ',',
#   'pop',
#   'stars',
#   'like',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'and',
#   'TV',
#   'shows',
#   'like',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   "'",
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'increase',
#   'children',
#   "'s",
#   '<UNKOWN>',
#   'to',
#   'have',
#   'spa',
#   '<UNKOWN>',
#   'such',
#   'as',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   'and',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   'Angeles',
#   'Radio',
#   'station',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'the',
#   'first',
#   'Pop',
#   'Chronicles',
#   '<UNKOWN>',
#   'in',
#   '1969',
#   '<UNKOWN>',
#   'or',
#   '<UNKOWN>',
#   'lettuce',
#   'is',
#   'a',
#   'type',
#   'of',
#   'lettuce',
#   '<END>'],
#  ['<START>',
#   '.They',
#   '<UNKOWN>',
#   'a',
#   '<UNKOWN>',
#   'and',
#   '<UNKOWN>',
#   'energy',
#   'source',
#   '.It',
#   '<END>'],
#  ['<START>',
#   'is',
#   'the',
#   'only',
#   'town',
#   'in',
#   'the',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'Council',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'Area',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'contains',
#   'less',
#   'energy',
#   'than',
#   'the',
#   'same',
#   'amount',
#   'of',
#   '<UNKOWN>',
#   ',',
#   'but',
#   'it',
#   'requires',
#   'less',
#   '<UNKOWN>',
#   '.The',
#   '<END>'],
#  ['<START>',
#   'two',
#   'starting',
#   'tribes',
#   'were',
#   'Drake',
#   'and',
#   'Morgan',
#   '<UNKOWN>',
#   'is',
#   'a',
#   'free',
#   ',',
#   'open',
#   'source',
#   'web',
#   '<UNKOWN>',
#   ',',
#   'that',
#   'was',
#   '<UNKOWN>',
#   'for',
#   'the',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'system',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   'theologians',
#   'use',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'and',
#   'argument',
#   'to',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   ',',
#   'test',
#   ',',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   'or',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   '.He',
#   'won',
#   'his',
#   'only',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'when',
#   'the',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'the',
#   'Seattle',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'in',
#   'the',
#   'national',
#   '<UNKOWN>',
#   'at',
#   'are',
#   'the',
#   '<UNKOWN>',
#   'of',
#   'the',
#   '<UNKOWN>',
#   'of',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   'The',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'is',
#   'a',
#   'DVD',
#   'by',
#   '<UNKOWN>',
#   'artist',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '.This',
#   '<END>'],
#  ['<START>',
#   'animal',
#   'is',
#   'seen',
#   'as',
#   'a',
#   '<UNKOWN>',
#   'by',
#   'some',
#   'people',
#   '.',
#   '<END>'],
#  ['<START>',
#   'In',
#   'the',
#   'United',
#   'Kingdom',
#   'the',
#   '<UNKOWN>',
#   'and',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'does',
#   'not',
#   'allow',
#   'some',
#   'ways',
#   'of',
#   '<UNKOWN>',
#   'them',
#   ',',
#   'and',
#   'to',
#   'remove',
#   'the',
#   '<UNKOWN>',
#   'from',
#   'the',
#   'area',
#   'may',
#   '<UNKOWN>',
#   'a',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'also',
#   'created',
#   'a',
#   'TV',
#   'series',
#   'he',
#   'called',
#   '``',
#   '<UNKOWN>',
#   'Ultraman',
#   ',',
#   "''",
#   '<UNKOWN>',
#   '-',
#   'aired',
#   'as',
#   'of',
#   'late',
#   'March',
#   '2008',
#   ',',
#   'a',
#   'joint',
#   'project',
#   'in',
#   'China',
#   '<UNKOWN>',
#   'his',
#   'own',
#   'Ultraman',
#   'and',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'to',
#   'the',
#   'project',
#   '<UNKOWN>',
#   'is',
#   'a',
#   'Dominican',
#   'province',
#   ',',
#   'located',
#   'in',
#   'the',
#   'northeastern',
#   'part',
#   'of',
#   'the',
#   'country',
#   ',',
#   '<UNKOWN>',
#   'the',
#   'whole',
#   'Samaná',
#   'Peninsula',
#   '.',
#   '<END>'],
#  ['<START>',
#   'Its',
#   'capital',
#   'city',
#   'is',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'de',
#   'Samaná',
#   ',',
#   'usually',
#   'called',
#   'just',
#   '``',
#   'Samaná',
#   "''",
#   '.He',
#   'has',
#   'had',
#   'many',
#   'operations',
#   'including',
#   'one',
#   'in',
#   '2006',
#   'for',
#   'a',
#   'brain',
#   'tumor',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   'in',
#   'this',
#   'field',
#   'are',
#   'called',
#   '<UNKOWN>',
#   '.Robinson',
#   '<END>'],
#  ['<START>', "'s", 'daughter', ',', '<UNKOWN>', '<END>'],
#  ['<START>',
#   ',',
#   'became',
#   'a',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   ',',
#   'director',
#   'of',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'for',
#   '<UNKOWN>',
#   ',',
#   'and',
#   'the',
#   'author',
#   'of',
#   'two',
#   'books',
#   'about',
#   'her',
#   'father',
#   '.He',
#   'was',
#   'named',
#   'after',
#   'his',
#   'mother',
#   "'s",
#   'brother',
#   'Henry',
#   '<UNKOWN>',
#   ',',
#   'a',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'who',
#   'died',
#   'only',
#   'three',
#   'years',
#   'earlier',
#   'at',
#   'the',
#   '<UNKOWN>',
#   'of',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   '.It',
#   'is',
#   'the',
#   'third',
#   '-',
#   'largest',
#   'city',
#   'in',
#   'Aargau',
#   'after',
#   '<UNKOWN>',
#   'and',
#   'Baden',
#   '.By',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'the',
#   '<UNKOWN>',
#   'heat',
#   ',',
#   '<UNKOWN>',
#   'uses',
#   'heat',
#   'that',
#   'would',
#   'be',
#   '<UNKOWN>',
#   'in',
#   'a',
#   'conventional',
#   'power',
#   'plant',
#   ',',
#   '<UNKOWN>',
#   'reaching',
#   'an',
#   '<UNKOWN>',
#   'of',
#   'up',
#   'to',
#   '70',
#   '%',
#   ',',
#   'compared',
#   'with',
#   'at',
#   'most',
#   '<UNKOWN>',
#   '%',
#   'for',
#   'the',
#   'conventional',
#   'plants',
#   '.The',
#   '<END>'],
#  ['<START>',
#   'city',
#   'was',
#   'named',
#   'after',
#   'the',
#   'Roman',
#   'general',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'who',
#   'founded',
#   'it',
#   'as',
#   'a',
#   'military',
#   'base',
#   'for',
#   'his',
#   'operations',
#   'in',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '.The',
#   '<END>'],
#  ['<START>',
#   'British',
#   'edible',
#   '<UNKOWN>',
#   'population',
#   'is',
#   'about',
#   '<UNKOWN>',
#   'and',
#   'is',
#   'found',
#   'in',
#   'a',
#   '200',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'between',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   'and',
#   '<UNKOWN>',
#   '.This',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'over',
#   'time',
#   '.She',
#   '<END>'],
#  ['<START>',
#   'now',
#   'is',
#   'a',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'on',
#   'climate',
#   'change',
#   'for',
#   'the',
#   'United',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '-',
#   'General',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '-',
#   'moon',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   'the',
#   'last',
#   'year',
#   ',',
#   'a',
#   '<UNKOWN>',
#   'growth',
#   'of',
#   '<UNKOWN>',
#   'tourists',
#   ',',
#   'especially',
#   'from',
#   'Germany',
#   ',',
#   'has',
#   'been',
#   '<UNKOWN>',
#   '.However',
#   ',',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'allows',
#   '<UNKOWN>',
#   'of',
#   'pre',
#   '-',
#   'historic',
#   'hurricane',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'on',
#   '<UNKOWN>',
#   'of',
#   'centuries',
#   'to',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'complied',
#   'and',
#   'gave',
#   'him',
#   'a',
#   'shot',
#   'at',
#   '<END>'],
#  ['<START>',
#   'the',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '-',
#   '<UNKOWN>',
#   '-',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   '.It',
#   'is',
#   'south',
#   'of',
#   '<UNKOWN>',
#   ',',
#   'north',
#   'of',
#   '<UNKOWN>',
#   'County',
#   'and',
#   'west',
#   'of',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'are',
#   'made',
#   'to',
#   'the',
#   '<UNKOWN>',
#   'five',
#   '<UNKOWN>',
#   '.The',
#   '<END>'],
#  ['<START>',
#   'British',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'is',
#   'made',
#   'of',
#   'two',
#   '<UNKOWN>',
#   ':',
#   'The',
#   'Life',
#   '<UNKOWN>',
#   'and',
#   'The',
#   '<UNKOWN>',
#   'and',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'of',
#   'the',
#   '<UNKOWN>',
#   'and',
#   '<UNKOWN>',
#   'is',
#   'commonly',
#   '<UNKOWN>',
#   'in',
#   'preparation',
#   'for',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '.In',
#   '<END>'],
#  ['<START>',
#   'the',
#   'early',
#   '20th',
#   'century',
#   ',',
#   'the',
#   'term',
#   'Old',
#   'Empire',
#   'was',
#   'sometimes',
#   'given',
#   'to',
#   'this',
#   '<UNKOWN>',
#   'of',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'in',
#   'an',
#   '<UNKOWN>',
#   'to',
#   '<UNKOWN>',
#   'Egypt',
#   ';',
#   'the',
#   'term',
#   'is',
#   'now',
#   'considered',
#   '<UNKOWN>',
#   'and',
#   'has',
#   'long',
#   'been',
#   'out',
#   'of',
#   'use',
#   'by',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'on',
#   'the',
#   'subject',
#   '.A',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'is',
#   'a',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'where',
#   'a',
#   'modeled',
#   'form',
#   '<UNKOWN>',
#   'out',
#   'from',
#   'a',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '.The',
#   'name',
#   'comes',
#   'from',
#   'the',
#   '<UNKOWN>',
#   'Valley',
#   'in',
#   'the',
#   '<UNKOWN>',
#   'Hills',
#   'in',
#   'Pakistan',
#   '.A',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'is',
#   'a',
#   'house',
#   'built',
#   'from',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '.The',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   '-',
#   '<UNKOWN>',
#   '-',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   ',',
#   'or',
#   '<UNKOWN>',
#   'is',
#   'a',
#   'U.S.',
#   '<UNKOWN>',
#   '-',
#   'economic',
#   'region',
#   'where',
#   '<UNKOWN>',
#   ',',
#   'Louisiana',
#   ',',
#   'Texas',
#   ',',
#   'and',
#   'Oklahoma',
#   '<UNKOWN>',
#   '.The',
#   '<UNKOWN>',
#   'age',
#   'is',
#   '36',
#   'years',
#   '.The',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'is',
#   'a',
#   'modern',
#   'main',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'in',
#   'United',
#   'States',
#   'service',
#   'as',
#   'well',
#   'as',
#   '<UNKOWN>',
#   'to',
#   'several',
#   'countries',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'is',
#   'a',
#   'book',
#   'that',
#   'was',
#   'written',
#   'by',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'in',
#   '1985',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   '-',
#   'sur',
#   '-',
#   '<UNKOWN>',
#   'is',
#   'a',
#   'commune',
#   'of',
#   'the',
#   'Ardèche',
#   'département',
#   'in',
#   'southern',
#   'France',
#   '.A',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'of',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'was',
#   'located',
#   'here',
#   '<UNKOWN>',
#   'were',
#   'once',
#   'thought',
#   'not',
#   'to',
#   'have',
#   '<UNKOWN>',
#   ',',
#   'but',
#   'some',
#   '<UNKOWN>',
#   'have',
#   'now',
#   'been',
#   '<UNKOWN>',
#   '.He',
#   'is',
#   'also',
#   'known',
#   'to',
#   'be',
#   'a',
#   'Death',
#   '<UNKOWN>',
#   'but',
#   'after',
#   'Voldemort',
#   'started',
#   'hunting',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   'the',
#   'woman',
#   'Snape',
#   'had',
#   '<UNKOWN>',
#   'since',
#   'he',
#   'was',
#   'a',
#   'child',
#   ',',
#   'he',
#   'asked',
#   '<UNKOWN>',
#   'Dumbledore',
#   'to',
#   'find',
#   'a',
#   '<UNKOWN>',
#   'place',
#   'for',
#   'the',
#   'Potters',
#   'because',
#   'he',
#   '<UNKOWN>',
#   'Voldemort',
#   'wanted',
#   'to',
#   'kill',
#   'their',
#   'son',
#   ',',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '.',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'Dumbledore',
#   'was',
#   'not',
#   'able',
#   'to',
#   'save',
#   'the',
#   'Potters',
#   ',',
#   'Snape',
#   "'s",
#   '<UNKOWN>',
#   'was',
#   'real',
#   'and',
#   '<UNKOWN>',
#   'deep',
#   ',',
#   'he',
#   'gained',
#   'Dumbledore',
#   "'s",
#   'trust',
#   '.On',
#   '<END>'],
#  ['<START>',
#   'March',
#   '10',
#   '2005',
#   ',',
#   '<UNKOWN>',
#   'and',
#   'WWE',
#   'decided',
#   'not',
#   'to',
#   'go',
#   'on',
#   'with',
#   'the',
#   'agreement',
#   'with',
#   '<UNKOWN>',
#   'TV',
#   ',',
#   'making',
#   'it',
#   'so',
#   '<UNKOWN>',
#   'and',
#   'other',
#   'WWE',
#   'programs',
#   'on',
#   'the',
#   'network',
#   'would',
#   '<UNKOWN>',
#   'when',
#   'their',
#   'deal',
#   '<UNKOWN>',
#   'in',
#   'September',
#   '2005',
#   '.The',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'is',
#   'home',
#   'to',
#   'an',
#   '<UNKOWN>',
#   'with',
#   'works',
#   'by',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   'Giovanni',
#   '<UNKOWN>',
#   'and',
#   '<UNKOWN>',
#   '.A',
#   '<END>'],
#  ['<START>',
#   'metropolitan',
#   '<UNKOWN>',
#   'is',
#   'a',
#   'type',
#   'of',
#   '<UNKOWN>',
#   'government',
#   'district',
#   'in',
#   'England',
#   'and',
#   'covers',
#   '<UNKOWN>',
#   'areas',
#   'within',
#   'metropolitan',
#   'counties',
#   '.White',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'up',
#   'in',
#   '<UNKOWN>',
#   'but',
#   'was',
#   'brought',
#   'back',
#   'by',
#   'their',
#   'singer',
#   'Mike',
#   '<UNKOWN>',
#   'in',
#   '1999',
#   'with',
#   'new',
#   'members',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   'author',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'as',
#   'one',
#   'of',
#   'his',
#   '<UNKOWN>',
#   'characters',
#   'to',
#   '<UNKOWN>',
#   'for',
#   'the',
#   'series',
#   ',',
#   '<UNKOWN>',
#   '``',
#   'I',
#   'want',
#   'to',
#   'go',
#   'on',
#   'a',
#   '<UNKOWN>',
#   'with',
#   '<UNKOWN>',
#   'just',
#   'like',
#   'him',
#   '<UNKOWN>',
#   "''",
#   '<END>'],
#  ['<START>',
#   '.The',
#   'stadium',
#   'has',
#   'also',
#   'hosted',
#   'several',
#   'music',
#   '<UNKOWN>',
#   ',',
#   'including',
#   'performances',
#   'by',
#   '<UNKOWN>',
#   'John',
#   ',',
#   '<UNKOWN>',
#   ',',
#   'Red',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   ',',
#   'and',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   '.It',
#   'is',
#   'the',
#   'capital',
#   'of',
#   '<UNKOWN>',
#   'Province',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   'finds',
#   '<UNKOWN>',
#   ',',
#   'who',
#   '<UNKOWN>',
#   'himself',
#   'to',
#   'be',
#   'a',
#   'giant',
#   '<UNKOWN>',
#   ',',
#   'but',
#   'he',
#   'is',
#   '<UNKOWN>',
#   'by',
#   '<UNKOWN>',
#   '.The',
#   'company',
#   'used',
#   'to',
#   'be',
#   'known',
#   'as',
#   'the',
#   'World',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'or',
#   'the',
#   'WWF',
#   '.This',
#   'is',
#   'primarily',
#   'used',
#   'in',
#   'articles',
#   'about',
#   'events',
#   'in',
#   'parts',
#   'of',
#   'the',
#   'world',
#   'where',
#   'the',
#   'day',
#   '<UNKOWN>',
#   'the',
#   'month',
#   'in',
#   'a',
#   'date',
#   '.The',
#   'subject',
#   'of',
#   'carbon',
#   'compounds',
#   'is',
#   'called',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'because',
#   'almost',
#   'all',
#   '<UNKOWN>',
#   ',',
#   'or',
#   'living',
#   'things',
#   ',',
#   'are',
#   'made',
#   'up',
#   'of',
#   'water',
#   'and',
#   'carbon',
#   'compounds',
#   '.Michael',
#   '<END>'],
#  ['<START>',
#   'David',
#   '<UNKOWN>',
#   'is',
#   'a',
#   'sports',
#   '<UNKOWN>',
#   'and',
#   'former',
#   'National',
#   'Football',
#   'League',
#   'player',
#   '<UNKOWN>',
#   'is',
#   '<UNKOWN>',
#   '20th',
#   'size',
#   'and',
#   '17th',
#   'in',
#   'the',
#   'number',
#   'of',
#   'counties',
#   '<UNKOWN>',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'to',
#   'his',
#   '<UNKOWN>',
#   'in',
#   'Rome',
#   ',',
#   '<UNKOWN>',
#   'wrote',
#   'a',
#   'series',
#   'of',
#   'letters',
#   ',',
#   'including',
#   'one',
#   'to',
#   '<UNKOWN>',
#   ',',
#   '<UNKOWN>',
#   'of',
#   '<UNKOWN>',
#   ',',
#   'who',
#   'had',
#   'also',
#   'known',
#   'John',
#   '.',
#   '<END>'],
#  ['<START>',
#   'These',
#   'letters',
#   'are',
#   'an',
#   'example',
#   'of',
#   'the',
#   'theology',
#   'of',
#   'the',
#   'earliest',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   "'s",
#   'most',
#   'important',
#   'city',
#   'is',
#   '<UNKOWN>',
#   '.',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'is',
#   '<UNKOWN>',
#   "'s",
#   'largest',
#   'religion',
#   '.A',
#   '<END>'],
#  ['<START>',
#   '<UNKOWN>',
#   'machine',
#   'is',
#   'used',
#   'to',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'together',
#   'with',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'was',
#   'hit',
#   'hard',
#   'by',
#   'the',
#   'June',
#   '2007',
#   '<UNKOWN>',
#   '.The',
#   'ancient',
#   '<UNKOWN>',
#   'painted',
#   '<UNKOWN>',
#   'showing',
#   'the',
#   'preparation',
#   'of',
#   'food',
#   '.While',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'is',
#   '<UNKOWN>',
#   'by',
#   'a',
#   'giant',
#   'named',
#   '<UNKOWN>',
#   'and',
#   'with',
#   'the',
#   'help',
#   'of',
#   '<UNKOWN>',
#   '<UNKOWN>',
#   'to',
#   'kill',
#   'him',
#   '<END>'],
#  ['<START>',
#   '.They',
#   'are',
#   'probably',
#   'better',
#   'known',
#   'today',
#   'as',
#   'the',
#   '<UNKOWN>',
#   'material',
#   'given',
#   'to',
#   '<UNKOWN>',
#   'and',
#   'other',
#   '<UNKOWN>',
#   'birds',
#   'as',
#   'a',
#   'source',
#   'of',
#   '<UNKOWN>',
#   'for',
#   'their',
#   '<UNKOWN>',
#   '.The',
#   '<END>'],
#  ['<START>', 'capital', 'is', 'the', 'town', 'of', '<UNKOWN>', '.', '<END>']]

# %%
def remove_infrequent_words(sents):
    word_counts = {}
    for s in sents:
        for w in s:
            if w in word_counts:
                word_counts[w] += 1
            else:
                word_counts[w] = 1

    threshold = 2
    filtered_sents = []
    for s in sents:
        new_s = []
        for w in s:
            if word_counts[w] < threshold:
                new_s.append('<UNKOWN>')
            else:
                new_s.append(w)
        filtered_sents.append(new_s)
    return filtered_sents



def make_word_to_ix(sents):
    word_to_ix = {}
    num_unique_words = 0
    for sent in sents:
        for word in sent:
            if word not in word_to_ix:
                word_to_ix[word] = num_unique_words
                num_unique_words += 1


    return word_to_ix

def sent_to_onehot_vecs(sent,word_to_ix):
    #note: this is not how you would do this in practice! 

    vecs = []
    for i in range(len(sent)):
        word = sent[i]
        word_index = word_to_ix[word]

        vec = torch.zeros(len(word_to_ix), dtype=torch.float32,requires_grad=False)
        vec[word_index] = 1
        vecs.append(vec)

    return vecs

def vectorize_sents(sents,word_to_ix):
    one_hot_vecs = []
    for s in sents:
        one_hot_vecs.append(sent_to_onehot_vecs(s,word_to_ix))
    return one_hot_vecs

def get_data():
    corpus = load_corpus()
    sents = segment_and_tokenize(corpus)
    word_to_ix = make_word_to_ix(sents)

    vectorized_sents = vectorize_sents(sents,word_to_ix)
    
    vocab_size = len(word_to_ix)

    return vectorized_sents, vocab_size

sents=[['The','dog','barked'],['The','cat','barked']]
word_to_ix = make_word_to_ix(sents2)
vectorized_sents = vectorize_sents(sents2,word_to_ix)
print(len(sents2))
print(len(word_to_ix))
print(len(vectorized_sents))
###### DATA PROCESSING ENDS #########
# Out:
# 678
# 1682
# 678

# %%
###### RNN DEFINITION STARTS #########

def elman_unit(word_embedding,h_previous,W_x,W_h,b):
    return torch.sigmoid(torch.matmul(W_x,word_embedding)+torch.matmul(W_h,h_previous)+b)

def embed_word(word,W_e):
    #word is a one-hot vector
    return torch.matmul(W_e,word)



def single_layer_perceptron(h,W_p):
    s = torch.matmul(W_p,h)
    softmax = nn.Softmax(dim=0)
    return softmax(s)


def network_forward(sent,param_dict):
    W_e = param_dict['W_e']
    W_x = param_dict['W_x'] 
    W_h = param_dict['W_h']
    W_p = param_dict['W_p']
    b = param_dict['b']


    h_previous = initialize_hidden_state(W_h.size()[1])
    
    predictions = []
    for i in range(len(sent)-1):
        current_word = sent[i]

        current_word_embedding = embed_word(current_word,W_e)

        h_current = elman_unit(current_word_embedding,h_previous, W_x,W_h,b)

        prediction = single_layer_perceptron(h_current,W_p)
        predictions.append(prediction)

        h_previous = h_current

    return predictions



###### RNN DEFINITION ENDS #########

# %%
#### LOSS FUNCTION BEGINS #######

def word_loss(word_probs, word):
    #outcome is a one-hot vector
    prob_of_word = torch.dot(word_probs,word)
    return -1*torch.log(prob_of_word)

def sent_loss(predictions, sent):
    L = torch.tensor(0,dtype=torch.float32)

    for i in range(len(predictions)):
        word_probs = predictions[i]
        observed_word = sent[i+1]
        L+=word_loss(word_probs,observed_word)

    return L


##### LOSS FUNCTION ENDS #######

# %%
#####WEIGHT INITIALIZATION STARTS #######

def initialize_weight_matrix(shape):
    return torch.rand(shape,dtype=torch.float32,requires_grad=True)

def initialize_hidden_state(shape):
    return torch.zeros(shape,dtype=torch.float32,requires_grad=False)


def initialize_parameters(embedding_dim,vocab_size,hidden_state_dim):
    W_e, W_x, W_h,W_p, b = (initialize_weight_matrix([embedding_dim,vocab_size]), 
        initialize_weight_matrix([hidden_state_dim,embedding_dim]), 
        initialize_weight_matrix([hidden_state_dim,hidden_state_dim]),
        initialize_weight_matrix([vocab_size,hidden_state_dim]),
        initialize_weight_matrix(hidden_state_dim))


    param_dict = {}
    param_dict['W_e'] = W_e
    param_dict['W_x'] = W_x
    param_dict['W_h'] = W_h
    param_dict['W_p'] = W_p
    param_dict['b'] = b

    return param_dict


#####WEIGHT INITIALIZATION ENDS #######

# %%
def train():
        
    vectorized_sents, vocab_size = get_data()
    

    num_epochs = 100

    hidden_state_dim = 10
    embedding_dim = 10
    learning_rate = 0.00001

    


    param_dict = initialize_parameters(embedding_dim,vocab_size,hidden_state_dim)

    optimizer = optim.SGD(list(param_dict.values()), lr=learning_rate)

    for i in range(num_epochs):

        total_loss = 0
        for s in vectorized_sents:
            optimizer.zero_grad()
            predictions = network_forward(s,param_dict)
            loss = sent_loss(predictions,s)
            total_loss += loss

            loss.backward() #this is the crucial step! this is where PyTorch automatically calculates gradients for all of the model parameters
            optimizer.step() #this is where gradient descent occurs: for each weight vector w, w = w-lr*w.grad
        print(total_loss)


if __name__=='__main__':
    train()
# Out:
# tensor(142693.0938, grad_fn=<ThAddBackward>)
# tensor(140887.8125, grad_fn=<ThAddBackward>)
# tensor(139088.6719, grad_fn=<ThAddBackward>)
# tensor(137297.3125, grad_fn=<ThAddBackward>)
# tensor(135517.2031, grad_fn=<ThAddBackward>)
# tensor(133752.4062, grad_fn=<ThAddBackward>)
# tensor(132009.4531, grad_fn=<ThAddBackward>)
# tensor(130296.3984, grad_fn=<ThAddBackward>)
# tensor(128624.8672, grad_fn=<ThAddBackward>)
# tensor(127009.3984, grad_fn=<ThAddBackward>)
# tensor(125468.3828, grad_fn=<ThAddBackward>)
# tensor(124022.6875, grad_fn=<ThAddBackward>)
# tensor(122693.7031, grad_fn=<ThAddBackward>)
# tensor(121499.9297, grad_fn=<ThAddBackward>)
# tensor(120452.6016, grad_fn=<ThAddBackward>)
# tensor(119552.5000, grad_fn=<ThAddBackward>)
# tensor(118788.4766, grad_fn=<ThAddBackward>)
# tensor(118140.7109, grad_fn=<ThAddBackward>)
# tensor(117584.7344, grad_fn=<ThAddBackward>)
# tensor(117096.5078, grad_fn=<ThAddBackward>)
# tensor(116655.4219, grad_fn=<ThAddBackward>)
# tensor(116246.2188, grad_fn=<ThAddBackward>)
# tensor(115857.8047, grad_fn=<ThAddBackward>)
# tensor(115483.1719, grad_fn=<ThAddBackward>)
# tensor(115117.7812, grad_fn=<ThAddBackward>)
# tensor(114758.9297, grad_fn=<ThAddBackward>)
# tensor(114405.2734, grad_fn=<ThAddBackward>)
# tensor(114055.9453, grad_fn=<ThAddBackward>)
# tensor(113710.5938, grad_fn=<ThAddBackward>)
# tensor(113369.1641, grad_fn=<ThAddBackward>)
# tensor(113031.5234, grad_fn=<ThAddBackward>)
# tensor(112697.8125, grad_fn=<ThAddBackward>)
# tensor(112368.2500, grad_fn=<ThAddBackward>)
# tensor(112043.0469, grad_fn=<ThAddBackward>)
# tensor(111722.2422, grad_fn=<ThAddBackward>)
# tensor(111406.0938, grad_fn=<ThAddBackward>)
# tensor(111094.8906, grad_fn=<ThAddBackward>)
# tensor(110788.6641, grad_fn=<ThAddBackward>)
# tensor(110487.7266, grad_fn=<ThAddBackward>)
# tensor(110192.3516, grad_fn=<ThAddBackward>)
# tensor(109902.5703, grad_fn=<ThAddBackward>)
# tensor(109618.7109, grad_fn=<ThAddBackward>)
# tensor(109340.8828, grad_fn=<ThAddBackward>)
# tensor(109069.2031, grad_fn=<ThAddBackward>)
# tensor(108803.9297, grad_fn=<ThAddBackward>)
# tensor(108545.1094, grad_fn=<ThAddBackward>)
# tensor(108292.9062, grad_fn=<ThAddBackward>)
# tensor(108047.3984, grad_fn=<ThAddBackward>)
# tensor(107808.6953, grad_fn=<ThAddBackward>)
# tensor(107576.7812, grad_fn=<ThAddBackward>)
# tensor(107351.8359, grad_fn=<ThAddBackward>)
# tensor(107133.5938, grad_fn=<ThAddBackward>)
# tensor(106922.2578, grad_fn=<ThAddBackward>)
# tensor(106717.7188, grad_fn=<ThAddBackward>)
# tensor(106519.9062, grad_fn=<ThAddBackward>)
# tensor(106328.6562, grad_fn=<ThAddBackward>)
# tensor(106143.9844, grad_fn=<ThAddBackward>)
# tensor(105965.6641, grad_fn=<ThAddBackward>)
# tensor(105793.4219, grad_fn=<ThAddBackward>)
# tensor(105627.3672, grad_fn=<ThAddBackward>)
# tensor(105467.0703, grad_fn=<ThAddBackward>)
# tensor(105312.2109, grad_fn=<ThAddBackward>)
# tensor(105162.9375, grad_fn=<ThAddBackward>)
# tensor(105018.7109, grad_fn=<ThAddBackward>)
# tensor(104879.5156, grad_fn=<ThAddBackward>)
# tensor(104744.9453, grad_fn=<ThAddBackward>)
# tensor(104614.9531, grad_fn=<ThAddBackward>)
# tensor(104489.2031, grad_fn=<ThAddBackward>)
# tensor(104367.4844, grad_fn=<ThAddBackward>)
# tensor(104249.6641, grad_fn=<ThAddBackward>)
# tensor(104135.5000, grad_fn=<ThAddBackward>)
# tensor(104024.8203, grad_fn=<ThAddBackward>)
# tensor(103917.4141, grad_fn=<ThAddBackward>)
# tensor(103813.0703, grad_fn=<ThAddBackward>)
# tensor(103711.7344, grad_fn=<ThAddBackward>)
# tensor(103613.3281, grad_fn=<ThAddBackward>)
# tensor(103517.6484, grad_fn=<ThAddBackward>)
# tensor(103424.4141, grad_fn=<ThAddBackward>)
# tensor(103333.7578, grad_fn=<ThAddBackward>)
# tensor(103245.3594, grad_fn=<ThAddBackward>)
# tensor(103159.3125, grad_fn=<ThAddBackward>)
# tensor(103075.3203, grad_fn=<ThAddBackward>)
# tensor(102993.4922, grad_fn=<ThAddBackward>)
# tensor(102913.5859, grad_fn=<ThAddBackward>)
# tensor(102835.5000, grad_fn=<ThAddBackward>)
# tensor(102759.4141, grad_fn=<ThAddBackward>)
# tensor(102685.0078, grad_fn=<ThAddBackward>)
# tensor(102612.2891, grad_fn=<ThAddBackward>)
# tensor(102541.2500, grad_fn=<ThAddBackward>)
# tensor(102471.7422, grad_fn=<ThAddBackward>)
# tensor(102403.7812, grad_fn=<ThAddBackward>)
# tensor(102337.3672, grad_fn=<ThAddBackward>)
# tensor(102272.2734, grad_fn=<ThAddBackward>)
# tensor(102208.5938, grad_fn=<ThAddBackward>)
# tensor(102146.1328, grad_fn=<ThAddBackward>)
# tensor(102085.0625, grad_fn=<ThAddBackward>)
# tensor(102025.1328, grad_fn=<ThAddBackward>)
# tensor(101966.6250, grad_fn=<ThAddBackward>)
# tensor(101909.1016, grad_fn=<ThAddBackward>)
# tensor(101852.7969, grad_fn=<ThAddBackward>)

# %% [markdown]
# # Written Section

# %% [markdown]
# ## Problem 1.
# The function load_corpus loads the text from sample_corpus.txt, and returns it as a string.
# The function segment_and_tokenize takes a single argument, corpus, which is assumed to be a string containing the entire corpus. Test this code on some simple examples, or on the corpus that is loaded by load_corpus. What does the function do to the string that it receives?

# %% [markdown]
# <font color='brown'>According to the corpus that it receives, the function segment_and_tokenize basically divides the passage into single tokens by space. Firstly, it loads the corpus and creates tokens. Notably, it removes infrequent words and returns $<UNKNOWN>$, then attaches $<START>$ in the beginning and $<END>$ in the end of each sentence. Generally, each sentence is divided based on the occurrence of period. The variable ‘sents’ is a list of sentences, where each sentence is itself a list of words. Finally, a list of frequently used words are returned.</font>

# %% [markdown]
# ## Problem 2
# The function get_data first loads the corpus, then creates a variable sents by calling segment_and_tokenize. It then passes sents to a function make_word_to_ix. The variable sents is assumed to be a list of sentences, where each sentence is itself a list of words. Explain what make_word_to_ix is doing.
# Hint: Try this on some simple examples. For example, set sents equal to: [[’The’,’dog’,’barked’],[’The’,’cat’,’barked’]].

# %% [markdown]
# <font color='brown'>This function takes in a list of sentences, and reads in all words in the sentences. It then builds a dictionary of individual words corresponding to unique indexes. This dictionary does not allow duplicated key, including $<UNKNOWN>$, $<START>$ and $<END>$. </font>

# %% [markdown]
# ## Problem 3.
# After the function get_data calls make_word_to_ix, it then calls a function vectorize_sents with arguments sents and word_to_ix.
# vectorize_sents turns the sentences into one-hot vectors. Explain how it does this.

# %% [markdown]
# <font color='brown'> The function called vectorize_sents turns the sentences into one-hot vectors. The thing returned is a list, in which lists of sentences are contained. The list of sentences include lists of one-hot vector words. Firstly, the function takes in sents and word_to_ix. Then, it calls function sent_to_onehot_vecs for each sentence in sents. Then, sent_to_onehot_vecs would convert each word in that sentence into one hot vector by using word_to_ix. This is how one hot vectors are created.</font>

# %% [markdown]
# ## Problem 4.
# The RNN defined in this code is being used for language modeling. As discussed in class, a language model is a probability distribution over sentences. If a sentence s consists of a sequence of words $w_0,...,w_{n−1}$, then the probability of the sentence is defined by:

# %% [markdown]
# $ P(s) = P(< start >,w_0,...,w_{n−1},< end >)
# = P (w_0| < start >) · P (w_1| < start >, w_0) · ... · P (< end > | < start >, w_0, ..., w_{n−1}) $

# %% [markdown]
# We will walk through the steps that the RNN is using to define a language model. The main function in this part of the code is network_forward. This function takes two arguments: sent and param_dict. The argument sent is a list of one-hot vectors, each representing a single word in the sentence. The argument param_dict is a dictionary containing all of the parameters needed to define the RNN. These are the parameters that will be learned later on.
# One of the first things that this function does is call embed_word, given a word (current_word) from the sentence and the weight matrix We. The function embed_word returns a word em- bedding for the word. How does embed_word generate a word embedding for current_word?

# %% [markdown]
# <font color='brown'>The function embed_word takes in two parameters: current_word, which is a word and the weight matrix w_e. This function performs matrix multiplication. The result gives out the word embedding for the passed-in current_word.</font>

# %% [markdown]
# ## Problem 5.
# After generating the wordembedding forcurrent_word,the functionnetwork_forward then calls the function elman_unit. This function will apply an Elman unit (as discussed in class) to two inputs: current_word_embedding and h_previous (the hidden state at the previous time point). The function elman_unit takes five arguments in total: current_word_embedding, h_previous, and three weight matrices.
#
# Describe mathematically what function elman_unit computes on its inputs.
#
# Hint: torch.matmul performs matrix multiplication: it multiplies a matrix by a vector. There is very good documentation for torch.matmul, and all other PyTorch functions, that can be found through Google.

# %% [markdown]
# <font color='brown'>
# $ v = w_x * word\_embedding + w_h * h\_previous + b $ <br>
#
# $ v = [v_1, v_2, ..., v_m] $<br>
#
# $ \sigma(v) = [\sigma(v_1), \sigma(v_2), ..., \sigma(v_m)] $ where $ \sigma $ is the sigmoid function, defined as $ \sigma(x)$ = $\frac{1}{1+e^{-x}} $
#
# </font>

# %% [markdown]
# ## Problem 6.
# After calling elman_unit and generating the value h_current, the function network_forward then calls the function single_layer_perceptron. The function single_layer_perceptron takes two arguments: h_current and the weight matrix Wp. Describe mathematically what the function single_layer_perceptron computes on its inputs.

# %% [markdown]
# <font color='brown'> Let $ S = w_p * h = [S_1, S_2, ..., S_k] $ where $ W_p $ is the weight matrix <br>
# Define softmax as $a(x)$, then $a(x)_j = \frac{e^{x_j}}{\sum_{i=1}^{k} e^{x_i}}$
# Then, the single_layer_perceptron returns <br>
# $a(S) = [a(s)_1, a(s)_2, ..., a(s)_k] $ <br>
# $ = [\frac{e^{s_1}}{\sum_{i=1}^{k} e^{S_k}}, \frac{e^{s_2}}{\sum_{i=1}^{k} e^{S_k}}, ..., \frac{e^{s_k}}{\sum_{i=1}^{k} e^{S_k}} ] $ </font>

# %% [markdown]
# ## Problem 7.
# The previous three problems have gone through the code describing the RNN. The function train is the code that is used for training the RNN. It first defines the dimen- sions for the different weight vectors, and then initializes the parameters. It uses PyTorch code for computing gradients automatically and optimizing the model weights.
# When you run the code by calling train, what happens to the loss function over time? Name one problem that the current implementation of the RNN is likely to have. We discussed several in class.
# Hint: What can go wrong with Elman networks?

# %% [markdown]
# <font color='brown'>The Loss Function decreases over time.
#
# The RNN function would possibly return a tiny gradient which would cause the RNN to forget the start of the sentence.
#
# Mathematically speaking, according to the vanishing gradient problem in class,</font>

# %% [markdown]
# <font color='brown'>$ \frac{\partial L}{\partial h_1} = \frac{\partial L}{\partial h_n} * (w_h)^{n-1} $ </font>

# %% [markdown]
# <font color='brown'>When $w_h$ is small, the latter term would be small and vice versa. <br>
# Large gradient, on the other hand, would lead to the missing of global minimum.</font>
